# %% [markdown]
# # Working with data

# %%
from typing import List, Dict
from collections import Counter
import math

import matplotlib.pyplot as plt

def bucketize(point: float, bucket_size: float) -> float:
    """Floor the point to the next lower multiple of bucket_size"""
    return bucket_size * math.floor(point / bucket_size)

def make_histogram(points: List[float], bucket_size: float) -> Dict[float, int]:
    """Buckets the points and counts how many in each bucket"""
    return Counter(bucketize(point, bucket_size) for point in points)

def plot_histogram(points: List[float], bucket_size: float, title: str = ""):
    histogram = make_histogram(points, bucket_size)
    plt.bar(histogram.keys(), histogram.values(), width=bucket_size)
    plt.title(title)

# %%
import random
from scratch.probability import inverse_normal_cdf


def random_normal() -> float:
    """Returns a random draw from a standard normal distribution"""
    return inverse_normal_cdf(random.random())

xs = [random_normal() for _ in range(1000)]
ys1 = [ x + random_normal() / 2 for x in xs]
ys2 = [-x + random_normal() / 2 for x in xs]

plt.scatter(xs, ys1, marker='.', color='white', label='ys1')
plt.scatter(xs, ys2, marker='.', color='gray',  label='ys2')
plt.xlabel('xs')
plt.ylabel('ys')
plt.legend(loc=9)
plt.title("Very Different Joint Distributions")
# plt.show()
# Out:
# Text(0.5, 1.0, 'Very Different Joint Distributions')

# %%
from scratch.statistics import correlation


assert 0.89 < correlation(xs, ys1) < 0.91
assert -0.91 < correlation(xs, ys2) < -0.89

from scratch.linear_algebra import Matrix, Vector, make_matrix

def correlation_matrix(data: List[Vector]) -> Matrix:
    """
    Returns the len(data) x len(data) matrix whose (i, j)-th entry
    is the correlation between data[i] and data[j]
    """
    def correlation_ij(i: int, j: int) -> float:
        return correlation(data[i], data[j])

    return make_matrix(len(data), len(data), correlation_ij)


vectors = [xs, ys1, ys2]
correlation_matrix(vectors)
# Out:
# [[1.0, 0.8933366949950308, -0.8990210993559374],
#  [0.8933366949950308, 1.0, -0.8128826794951244],
#  [-0.8990210993559373, -0.8128826794951244, 1.0]]

# %%
import datetime

stock_price = {'closing_price': 102.06,
               'date': datetime.date(2014, 8, 29),
               'symbol': 'AAPL'}

# %%
stock_price
# Out:
# {'closing_price': 102.06, 'date': datetime.date(2014, 8, 29), 'symbol': 'AAPL'}

# %% [markdown]
# ## NamedTuple

# %%
from typing import NamedTuple

class StockPrice(NamedTuple):
    symbol: str
    date: datetime.date
    closing_price: float

    def is_high_tech(self) -> bool:
        """It's a class, so we can add methods too"""
        return self.symbol in ['MSFT', 'GOOG', 'FB', 'AMZN', 'AAPL']

price = StockPrice('MSFT', datetime.date(2018, 12, 14), 106.03)

assert price.symbol == 'MSFT'
assert price.closing_price == 106.03
assert price.is_high_tech()

price
# Out:
# StockPrice(symbol='MSFT', date=datetime.date(2018, 12, 14), closing_price=106.03)

# %%
# caveat
from typing import NamedTuple

class Employee(NamedTuple):
    name: str
    id: int
    
employee = Employee('Alice', 123)
employee.name = 'Bob'  # This will raise an AttributeError because NamedTuple instances are immutable, contrary to dataclasses
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       5     id: int
#       7 employee = Employee('Alice', 123)
# ----> 8 employee.name = 'Bob'  # This will raise an AttributeError
#
# AttributeError: can't set attribute

# %%
StockPrice.symbol # shows the index
# Out:
# _tuplegetter(0, 'Alias for field number 0')

# %%
price.date # shows the value
# Out:
# datetime.date(2018, 12, 14)

# %% [markdown]
# ## Parser
#
# good for Lists

# %%
from dateutil.parser import parse

datum = "vandaag is 2023-2-14"
p_datum = parse(datum, fuzzy=True).date() # this first does date+time, then date-only
p_datum
# Out:
# datetime.date(2023, 2, 14)

# %%
from dateutil.parser import parse

def parse_row(row: List[str]) -> StockPrice:
    symbol, date, closing_price = row
    return StockPrice(symbol=symbol,
                      date=parse(date).date(),            # this is where the external module is used
                      closing_price=float(closing_price))

# Now test our function ON A LIST
stock = parse_row(["MSFT", "2018-12-14", "106.03"])

stock
# Out:
# StockPrice(symbol='MSFT', date=datetime.date(2018, 12, 14), closing_price=106.03)

# %%
from typing import Optional
import re

def try_parse_row(row: List[str]) -> Optional[StockPrice]:
    symbol, date_, closing_price_ = row

    # Stock symbol should be all capital letters
    if not re.match(r"^[A-Z]+$", symbol):
        return None

    try:
        date = parse(date_).date()
    except ValueError:
        return None

    try:
        closing_price = float(closing_price_)
    except ValueError:
        return None

    return StockPrice(symbol, date, closing_price)

# %%
import csv

with open("other/stocks.csv", "r") as f:
    reader = csv.DictReader(f)
    rows = [[row['Symbol'], row['Date'], row['Close']]
            for row in reader]

# skip header
maybe_data = [try_parse_row(row) for row in rows]

# This is just to make mypy happy
data = [sp for sp in maybe_data if sp is not None]

data
# Out:
# [StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 12), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 15), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 16), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 17), closing_price=0.462054),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 18), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 19), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 22), closing_price=0.529018),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 23), closing_price=0.551339),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 24), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 26), closing_price=0.633929),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 29), closing_price=0.642857),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 30), closing_price=0.627232),
#  StockPrice(symbol='AAPL', date=datetime.date(1980, 12, 31), closing_price=0.609375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 2), closing_price=0.616071),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 5), closing_price=0.602679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 6), closing_price=0.575893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 7), closing_price=0.551339),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 8), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 9), closing_price=0.569196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 12), closing_price=0.564732),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 13), closing_price=0.544643),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 14), closing_price=0.546875),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 15), closing_price=0.558036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 16), closing_price=0.553571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 19), closing_price=0.587054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 20), closing_price=0.569196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 21), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 22), closing_price=0.587054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 23), closing_price=0.584821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 26), closing_price=0.575893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 27), closing_price=0.571429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 28), closing_price=0.553571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 29), closing_price=0.533482),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 1, 30), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 2), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 3), closing_price=0.493304),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 4), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 5), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 6), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 9), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 10), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 11), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 12), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 13), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 17), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 18), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 19), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 20), closing_price=0.433036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 23), closing_price=0.439732),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 24), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 25), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 26), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 2, 27), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 2), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 3), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 4), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 5), closing_price=0.462054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 6), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 9), closing_price=0.421875),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 10), closing_price=0.401786),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 11), closing_price=0.386161),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 12), closing_price=0.401786),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 13), closing_price=0.397321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 16), closing_price=0.412946),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 17), closing_price=0.433036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 18), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 19), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 20), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 23), closing_price=0.477679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 24), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 25), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 26), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 27), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 30), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 3, 31), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 1), closing_price=0.433036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 2), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 3), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 6), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 7), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 8), closing_price=0.482143),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 9), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 10), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 13), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 14), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 15), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 16), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 20), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 21), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 22), closing_price=0.508929),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 23), closing_price=0.522321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 24), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 27), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 28), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 29), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 4, 30), closing_price=0.506696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 1), closing_price=0.506696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 4), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 5), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 6), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 7), closing_price=0.495536),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 8), closing_price=0.5),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 11), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 12), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 13), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 14), closing_price=0.479911),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 15), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 18), closing_price=0.5),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 19), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 20), closing_price=0.506696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 21), closing_price=0.535714),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 22), closing_price=0.560268),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 26), closing_price=0.558036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 27), closing_price=0.589286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 28), closing_price=0.589286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 5, 29), closing_price=0.591518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 1), closing_price=0.591518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 2), closing_price=0.5625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 3), closing_price=0.5625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 4), closing_price=0.573661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 5), closing_price=0.564732),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 8), closing_price=0.544643),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 9), closing_price=0.555804),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 10), closing_price=0.5625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 11), closing_price=0.587054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 12), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 15), closing_price=0.578125),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 16), closing_price=0.566964),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 17), closing_price=0.558036),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 18), closing_price=0.555804),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 19), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 22), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 23), closing_price=0.529018),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 24), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 25), closing_price=0.526786),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 26), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 29), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 6, 30), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 1), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 2), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 6), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 7), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 8), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 9), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 10), closing_price=0.397321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 13), closing_price=0.40625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 14), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 15), closing_price=0.435268),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 16), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 17), closing_price=0.462054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 20), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 21), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 22), closing_price=0.404018),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 23), closing_price=0.415179),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 24), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 27), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 28), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 29), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 30), closing_price=0.439732),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 7, 31), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 3), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 4), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 5), closing_price=0.462054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 6), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 7), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 11), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 12), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 13), closing_price=0.415179),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 14), closing_price=0.408482),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 17), closing_price=0.395089),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 18), closing_price=0.386161),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 19), closing_price=0.381696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 20), closing_price=0.386161),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 21), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 24), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 25), closing_price=0.345982),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 26), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 27), closing_price=0.341518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 28), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 8, 31), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 1), closing_price=0.381696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 2), closing_price=0.388393),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 3), closing_price=0.368304),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 4), closing_price=0.363839),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 8), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 9), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 10), closing_price=0.354911),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 11), closing_price=0.350446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 14), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 15), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 16), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 17), closing_price=0.314732),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 18), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 21), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 22), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 23), closing_price=0.294643),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 24), closing_price=0.292411),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 25), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 28), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 29), closing_price=0.270089),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 9, 30), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 1), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 2), closing_price=0.294643),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 5), closing_price=0.303571),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 6), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 7), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 8), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 9), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 12), closing_price=0.34375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 13), closing_price=0.34375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 14), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 15), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 16), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 19), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 20), closing_price=0.350446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 21), closing_price=0.350446),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 22), closing_price=0.348214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 23), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 26), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 27), closing_price=0.345982),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 28), closing_price=0.357143),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 29), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 10, 30), closing_price=0.357143),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 2), closing_price=0.357143),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 3), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 4), closing_price=0.34375),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 5), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 6), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 9), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 10), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 11), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 12), closing_price=0.348214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 13), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 16), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 17), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 18), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 19), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 20), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 23), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 24), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 25), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 27), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 11, 30), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 1), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 2), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 3), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 4), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 7), closing_price=0.341518),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 8), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 9), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 10), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 11), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 14), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 15), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 16), closing_price=0.348214),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 17), closing_price=0.377232),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 18), closing_price=0.408482),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 21), closing_price=0.390625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 22), closing_price=0.397321),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 23), closing_price=0.388393),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 24), closing_price=0.390625),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 28), closing_price=0.372768),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 29), closing_price=0.379464),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 30), closing_price=0.395089),
#  StockPrice(symbol='AAPL', date=datetime.date(1981, 12, 31), closing_price=0.395089),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 4), closing_price=0.392857),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 5), closing_price=0.372768),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 6), closing_price=0.368304),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 7), closing_price=0.339286),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 8), closing_price=0.354911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 11), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 12), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 13), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 14), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 15), closing_price=0.357143),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 18), closing_price=0.363839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 19), closing_price=0.354911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 20), closing_price=0.361607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 21), closing_price=0.368304),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 22), closing_price=0.370536),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 25), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 26), closing_price=0.345982),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 27), closing_price=0.348214),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 28), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 1, 29), closing_price=0.363839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 1), closing_price=0.359375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 2), closing_price=0.361607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 3), closing_price=0.361607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 4), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 5), closing_price=0.352679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 8), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 9), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 10), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 11), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 12), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 16), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 17), closing_price=0.332589),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 18), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 19), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 22), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 23), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 24), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 25), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 2, 26), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 1), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 2), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 3), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 4), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 5), closing_price=0.296875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 8), closing_price=0.292411),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 9), closing_price=0.294643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 10), closing_price=0.290179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 11), closing_price=0.290179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 12), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 15), closing_price=0.270089),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 16), closing_price=0.265625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 17), closing_price=0.252232),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 18), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 19), closing_price=0.296875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 22), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 23), closing_price=0.314732),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 24), closing_price=0.296875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 25), closing_price=0.294643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 26), closing_price=0.290179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 29), closing_price=0.296875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 30), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 3, 31), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 1), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 2), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 5), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 6), closing_price=0.314732),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 7), closing_price=0.310268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 8), closing_price=0.3125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 12), closing_price=0.310268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 13), closing_price=0.285714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 14), closing_price=0.287946),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 15), closing_price=0.292411),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 16), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 19), closing_price=0.294643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 20), closing_price=0.28125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 21), closing_price=0.279018),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 22), closing_price=0.274554),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 23), closing_price=0.274554),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 26), closing_price=0.28125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 27), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 28), closing_price=0.261161),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 29), closing_price=0.261161),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 4, 30), closing_price=0.263393),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 3), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 4), closing_price=0.28125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 5), closing_price=0.276786),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 6), closing_price=0.285714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 7), closing_price=0.290179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 10), closing_price=0.285714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 11), closing_price=0.276786),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 12), closing_price=0.270089),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 13), closing_price=0.272321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 14), closing_price=0.261161),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 17), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 18), closing_price=0.252232),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 19), closing_price=0.25),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 20), closing_price=0.252232),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 21), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 24), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 25), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 26), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 27), closing_price=0.25),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 5, 28), closing_price=0.25),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 1), closing_price=0.245536),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 2), closing_price=0.25),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 3), closing_price=0.241071),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 4), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 7), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 8), closing_price=0.232143),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 9), closing_price=0.227679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 10), closing_price=0.229911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 11), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 14), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 15), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 16), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 17), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 18), closing_price=0.229911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 21), closing_price=0.229911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 22), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 23), closing_price=0.245536),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 24), closing_price=0.245536),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 25), closing_price=0.236607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 28), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 29), closing_price=0.227679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 6, 30), closing_price=0.227679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 1), closing_price=0.225446),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 2), closing_price=0.214286),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 6), closing_price=0.205357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 7), closing_price=0.205357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 8), closing_price=0.196429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 9), closing_price=0.203125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 12), closing_price=0.207589),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 13), closing_price=0.220982),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 14), closing_price=0.223214),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 15), closing_price=0.227679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 16), closing_price=0.236607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 19), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 20), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 21), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 22), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 23), closing_price=0.252232),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 26), closing_price=0.241071),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 27), closing_price=0.241071),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 28), closing_price=0.229911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 29), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 7, 30), closing_price=0.241071),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 2), closing_price=0.247768),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 3), closing_price=0.232143),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 4), closing_price=0.229911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 5), closing_price=0.220982),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 6), closing_price=0.21875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 9), closing_price=0.220982),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 10), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 11), closing_price=0.236607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 12), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 13), closing_price=0.234375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 16), closing_price=0.238839),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 17), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 18), closing_price=0.254464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 19), closing_price=0.256696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 20), closing_price=0.263393),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 23), closing_price=0.274554),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 24), closing_price=0.287946),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 25), closing_price=0.308036),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 26), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 27), closing_price=0.301339),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 30), closing_price=0.305804),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 8, 31), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 1), closing_price=0.3125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 2), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 3), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 7), closing_price=0.310268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 8), closing_price=0.321429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 9), closing_price=0.314732),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 10), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 13), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 14), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 15), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 16), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 17), closing_price=0.316964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 20), closing_price=0.319196),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 21), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 22), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 23), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 24), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 27), closing_price=0.323661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 28), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 29), closing_price=0.328125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 9, 30), closing_price=0.325893),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 1), closing_price=0.330357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 4), closing_price=0.334821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 5), closing_price=0.337054),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 6), closing_price=0.361607),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 7), closing_price=0.390625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 8), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 11), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 12), closing_price=0.415179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 13), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 14), closing_price=0.421875),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 15), closing_price=0.410714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 18), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 19), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 20), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 21), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 22), closing_price=0.462054),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 25), closing_price=0.435268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 26), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 27), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 28), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 10, 29), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 1), closing_price=0.477679),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 2), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 3), closing_price=0.549107),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 4), closing_price=0.553571),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 5), closing_price=0.537946),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 8), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 9), closing_price=0.533482),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 10), closing_price=0.553571),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 11), closing_price=0.589286),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 12), closing_price=0.578125),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 15), closing_price=0.564732),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 16), closing_price=0.535714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 17), closing_price=0.560268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 18), closing_price=0.560268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 19), closing_price=0.551339),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 22), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 23), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 24), closing_price=0.526786),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 26), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 29), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 11, 30), closing_price=0.569196),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 1), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 2), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 3), closing_price=0.566964),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 6), closing_price=0.598214),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 7), closing_price=0.604911),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 8), closing_price=0.591518),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 9), closing_price=0.5625),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 10), closing_price=0.522321),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 13), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 14), closing_price=0.506696),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 15), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 16), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 17), closing_price=0.537946),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 20), closing_price=0.535714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 21), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 22), closing_price=0.555804),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 23), closing_price=0.571429),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 27), closing_price=0.584821),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 28), closing_price=0.580357),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 29), closing_price=0.560268),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 30), closing_price=0.535714),
#  StockPrice(symbol='AAPL', date=datetime.date(1982, 12, 31), closing_price=0.533482),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 3), closing_price=0.508929),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 4), closing_price=0.537946),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 5), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 6), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 7), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 10), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 11), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 12), closing_price=0.549107),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 13), closing_price=0.549107),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 14), closing_price=0.589286),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 17), closing_price=0.609375),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 18), closing_price=0.595982),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 19), closing_price=0.600446),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 20), closing_price=0.667411),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 21), closing_price=0.667411),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 24), closing_price=0.629464),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 25), closing_price=0.654018),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 26), closing_price=0.680804),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 27), closing_price=0.727679),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 28), closing_price=0.732143),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 1, 31), closing_price=0.729911),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 1), closing_price=0.745536),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 2), closing_price=0.765625),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 3), closing_price=0.796875),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 4), closing_price=0.785714),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 7), closing_price=0.754464),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 8), closing_price=0.747768),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 9), closing_price=0.754464),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 10), closing_price=0.803571),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 11), closing_price=0.830357),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 14), closing_price=0.825893),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 15), closing_price=0.810268),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 16), closing_price=0.794643),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 17), closing_price=0.785714),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 18), closing_price=0.810268),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 22), closing_price=0.830357),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 23), closing_price=0.837054),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 24), closing_price=0.859375),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 25), closing_price=0.834821),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 2, 28), closing_price=0.814732),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 1), closing_price=0.828125),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 2), closing_price=0.834821),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 3), closing_price=0.808036),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 4), closing_price=0.796875),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 7), closing_price=0.78125),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 8), closing_price=0.756696),
#  StockPrice(symbol='AAPL', date=datetime.date(1983, 3, 9), closing_price=0.779018),
# ...
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 1), closing_price=0.482143),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 2), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 5), closing_price=0.477679),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 6), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 7), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 8), closing_price=0.479911),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 9), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 12), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 13), closing_price=0.482143),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 14), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 15), closing_price=0.477679),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 16), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 19), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 20), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 21), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 22), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 23), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 26), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 27), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 28), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 29), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 3, 30), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 2), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 3), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 4), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 5), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 6), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 9), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 10), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 11), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 12), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 13), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 16), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 17), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 18), closing_price=0.5),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 19), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 23), closing_price=0.506696),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 24), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 25), closing_price=0.493304),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 26), closing_price=0.53125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 27), closing_price=0.537946),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 4, 30), closing_price=0.560268),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 1), closing_price=0.59375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 2), closing_price=0.589286),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 3), closing_price=0.564732),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 4), closing_price=0.537946),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 7), closing_price=0.555804),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 8), closing_price=0.587054),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 9), closing_price=0.591518),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 10), closing_price=0.591518),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 11), closing_price=0.575893),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 14), closing_price=0.564732),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 15), closing_price=0.569196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 16), closing_price=0.544643),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 17), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 18), closing_price=0.53125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 21), closing_price=0.569196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 22), closing_price=0.551339),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 23), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 24), closing_price=0.524554),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 25), closing_price=0.526786),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 29), closing_price=0.524554),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 30), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 5, 31), closing_price=0.524554),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 1), closing_price=0.542411),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 4), closing_price=0.529018),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 5), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 6), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 7), closing_price=0.513393),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 8), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 11), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 12), closing_price=0.520089),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 13), closing_price=0.53125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 14), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 15), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 18), closing_price=0.529018),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 19), closing_price=0.524554),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 20), closing_price=0.540179),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 21), closing_price=0.517857),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 22), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 25), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 26), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 27), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 28), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 6, 29), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 2), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 3), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 5), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 6), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 9), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 10), closing_price=0.479911),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 11), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 12), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 13), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 16), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 17), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 18), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 19), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 20), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 23), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 24), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 25), closing_price=0.477679),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 26), closing_price=0.486607),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 27), closing_price=0.484375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 30), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 7, 31), closing_price=0.455357),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 1), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 2), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 3), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 6), closing_price=0.522321),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 7), closing_price=0.529018),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 8), closing_price=0.508929),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 9), closing_price=0.53125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 10), closing_price=0.508929),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 13), closing_price=0.535714),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 14), closing_price=0.515625),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 15), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 16), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 17), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 20), closing_price=0.488839),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 21), closing_price=0.508929),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 22), closing_price=0.5),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 23), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 24), closing_price=0.502232),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 27), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 28), closing_price=0.504464),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 29), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 30), closing_price=0.482143),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 8, 31), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 4), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 5), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 6), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 7), closing_price=0.473214),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 10), closing_price=0.470982),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 11), closing_price=0.479911),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 12), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 13), closing_price=0.491071),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 14), closing_price=0.497768),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 17), closing_price=0.511161),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 18), closing_price=0.493304),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 19), closing_price=0.482143),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 20), closing_price=0.484375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 21), closing_price=0.479911),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 24), closing_price=0.475446),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 25), closing_price=0.466518),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 26), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 27), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 9, 28), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 1), closing_price=0.4375),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 2), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 3), closing_price=0.448661),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 4), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 5), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 8), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 9), closing_price=0.439732),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 10), closing_price=0.426339),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 11), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 12), closing_price=0.40625),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 15), closing_price=0.428571),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 16), closing_price=0.426339),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 17), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 18), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 19), closing_price=0.457589),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 22), closing_price=0.453125),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 23), closing_price=0.464286),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 24), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 25), closing_price=0.450893),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 26), closing_price=0.439732),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 29), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 30), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 10, 31), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 1), closing_price=0.446429),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 2), closing_price=0.444196),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 5), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 6), closing_price=0.46875),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 7), closing_price=0.459821),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 8), closing_price=0.441964),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 9), closing_price=0.415179),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 12), closing_price=0.430804),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 13), closing_price=0.419643),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 14), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 15), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 16), closing_price=0.415179),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 19), closing_price=0.390625),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 20), closing_price=0.404018),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 21), closing_price=0.412946),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 23), closing_price=0.424107),
#  StockPrice(symbol='AAPL', date=datetime.date(1984, 11, 26), closing_price=0.428571),
#  ...]

# %%
# another way
import csv

data: List[StockPrice] = []

with open("other/comma_delimited_stock_prices.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        maybe_stock = try_parse_row(row)
        if maybe_stock is None:
            print(f"skipping invalid row: {row}")
        else:
            data.append(maybe_stock)
data
# Out:
# skipping invalid row: ['MSFT', '6/19/2014', 'n/a']
# [StockPrice(symbol='AAPL', date=datetime.date(2014, 6, 20), closing_price=90.91),
#  StockPrice(symbol='MSFT', date=datetime.date(2014, 6, 20), closing_price=41.68),
#  StockPrice(symbol='FB', date=datetime.date(3014, 6, 20), closing_price=64.5),
#  StockPrice(symbol='AAPL', date=datetime.date(2014, 6, 19), closing_price=91.86),
#  StockPrice(symbol='FB', date=datetime.date(2014, 6, 19), closing_price=64.34)]

# %%
max_aapl_price = max(stock_price.closing_price
                     for stock_price in data
                     if stock_price.symbol == "AAPL")
max_aapl_price
# Out:
# 232.070007

# %%
from collections import defaultdict

max_prices: Dict[str, float] = defaultdict(lambda: float('-inf'))

for sp in data:
    symbol, closing_price = sp.symbol, sp.closing_price
    if closing_price > max_prices[symbol]:
        max_prices[symbol] = closing_price

max_prices
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'AAPL': 232.070007,
#              'MSFT': 115.610001,
#              'FB': 217.5,
#              'GOOG': 1268.329956})

# %%
from typing import List
from collections import defaultdict

# Collect the prices by symbol
prices: Dict[str, List[StockPrice]] = defaultdict(list)

for sp in data:
    prices[sp.symbol].append(sp)

# Order the prices by date
prices = {symbol: sorted(symbol_prices)
          for symbol, symbol_prices in prices.items()}

def pct_change(yesterday: StockPrice, today: StockPrice) -> float:
    return today.closing_price / yesterday.closing_price - 1

# define a new NamedTuple class
class DailyChange(NamedTuple):
    symbol: str
    date: datetime.date
    pct_change: float

def day_over_day_changes(prices: List[StockPrice]) -> List[DailyChange]:
    """
    Assumes prices are for one stock and are in order
    """
    return [DailyChange(symbol=today.symbol,
                        date=today.date,
                        pct_change=pct_change(yesterday, today))
            for yesterday, today in zip(prices, prices[1:])]

all_changes = [change
               for symbol_prices in prices.values()
               for change in day_over_day_changes(symbol_prices)]

all_changes
# Out:
# [DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 15), pct_change=-0.05217445504710816),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 16), pct_change=-0.07339392980372261),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 17), pct_change=0.0247531010683244),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 18), pct_change=0.02898362529055043),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 19), pct_change=0.061033219335108635),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 22), pct_change=0.04867344349646352),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 23), pct_change=0.04219327130645856),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 24), pct_change=0.052631865331493),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 26), pct_change=0.09230869964521826),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 29), pct_change=0.014083596112498542),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 30), pct_change=-0.024305560956791372),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 31), pct_change=-0.02846952961583593),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 2), pct_change=0.010988307692307853),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 5), pct_change=-0.021737754252350916),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 6), pct_change=-0.044444886913265536),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 7), pct_change=-0.04263639252430562),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 8), pct_change=-0.020241629922788107),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 9), pct_change=0.053717378868856525),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 12), pct_change=-0.007842641199165223),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 13), pct_change=-0.03557262559939944),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 14), pct_change=0.0040980972857449505),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 15), pct_change=0.02040868571428578),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 16), pct_change=-0.00800127590334665),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 19), pct_change=0.06048546618229622),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 20), pct_change=-0.03041968881908641),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 21), pct_change=0.01960835986198073),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 22), pct_change=0.011539448994325907),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 23), pct_change=-0.003803738667992995),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 26), pct_change=-0.015266209660733887),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 27), pct_change=-0.007751439937627391),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 28), pct_change=-0.03125147656139249),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 29), pct_change=-0.03628983454696877),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 30), pct_change=-0.05439358778740422),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 2), pct_change=-0.05752243965872694),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 3), pct_change=0.037560522120283046),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 4), pct_change=0.03619877398115556),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 5), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 6), pct_change=0.00436653031041101),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 9), pct_change=-0.05217445504710816),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 10), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 11), pct_change=-0.032110101169937955),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2,

#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 29), pct_change=0.005075818907880336),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 30), pct_change=0.010102632793621114),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 31), pct_change=-0.005001915198161511),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 1), pct_change=0.005027060126610916),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 2), pct_change=-0.005001915198161511),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 5), pct_change=-0.005024808868157149),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 6), pct_change=0.06060674625082574),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 7), pct_change=-0.01904853333333334),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 8), pct_change=-0.03883467697212606),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 9), pct_change=-0.06060448362310056),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 12), pct_change=0.03763436975376888),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 13), pct_change=-0.025907373190592553),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 14), pct_change=0.010637613399961499),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 15), pct_change=0.0),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 16), pct_change=-0.02105129130148753),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 19), pct_change=-0.05914075615577863),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 20), pct_change=0.03428608),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 21), pct_change=0.022098025335504756),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 23), pct_change=0.027027746969337407),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 26), pct_change=0.010525645650743654),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 27), pct_change=0.02604235937569288),
#  ...]

# %%
max_change = max(all_changes, key=lambda change: change.pct_change) # change is local
max_change
# Out:
# DailyChange(symbol='AAPL', date=datetime.date(1997, 8, 6), pct_change=0.33227854830957937)

# %%
all_changes.sort(key=lambda x: x.pct_change)
all_changes
# Out:
# [DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 29), pct_change=-0.5186915679972073),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 19), pct_change=-0.3011588936357591),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 9, 23), pct_change=-0.25384547786965617),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 19), pct_change=-0.2435234393406739),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 7, 16), pct_change=-0.2307692910166621),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 26), pct_change=-0.21126751676253708),
#  DailyChange(symbol='FB', date=datetime.date(2018, 7, 26), pct_change=-0.18960921839080458),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 26), pct_change=-0.1865287448256926),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 9, 29), pct_change=-0.1791952510917031),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 1, 6), pct_change=-0.17816103791777915),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 7, 18), pct_change=-0.17171308141140085),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 12, 6), pct_change=-0.15808878633205026),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 4, 24), pct_change=-0.15597783056215364),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 6, 19), pct_change=-0.15037247635285822),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 11, 8), pct_change=-0.14881066666666676),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 4, 3), pct_change=-0.14470588235294113),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 5, 1), pct_change=-0.1409092158677504),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 3, 7), pct_change=-0.1370971488029431),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 4, 15), pct_change=-0.13240429268292686),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 9, 25), pct_change=-0.12977281976396227),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 7, 17), pct_change=-0.12485949045005396),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 9, 21), pct_change=-0.12411086175004715),
#  DailyChange(symbol='AAPL', date=datetime.date(2013, 1, 24), pct_change=-0.1235579463434564),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 9, 7), pct_change=-0.12063431111111111),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 11, 30), pct_change=-0.11815561959654175),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 1, 22), pct_change=-0.1171309657962315),
#  DailyChange(symbol='FB', date=datetime.date(2012, 7, 27), pct_change=-0.11694603351955313),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 9, 29), pct_change=-0.11609132294497115),
#  DailyChange(symbol='MSFT', date=datetime.date(2013, 7, 19), pct_change=-0.11399546032718577),
#  DailyChange(symbol='MSFT', date=datetime.date(2006, 4, 28), pct_change=-0.11376146788990826),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 15), pct_change=-0.11373873873873874),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 1, 14), pct_change=-0.11021464261757297),
#  DailyChange(symbol='FB', date=datetime.date(2012, 5, 21), pct_change=-0.10986139157729535),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 1, 23), pct_change=-0.10646355392134266),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 6, 9), pct_change=-0.10606061463116079),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 12, 2), pct_change=-0.1056348581623493),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 9, 15), pct_change=-0.10312473093741925),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 8, 12), pct_change=-0.10178151275831249),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 3, 7), pct_change=-0.10152320049484687),
#  DailyChange(symbol='AAPL', date=datetime.date(1988, 1, 8), pct_change=-0.10112402676421983),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 9, 23), pct_change=-0.099555544228347),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 10, 16), pct_change=-0.09909885366436921),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 1, 27), pct_change=-0.09880213618264999),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 7, 18), pct_change=-0.09770546368808097),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 10, 16), pct_change=-0.0971125738730031),
#  DailyChange(symbol='FB', date=datetime.date(2012, 5, 29), pct_change=-0.09620808523973678),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 7, 23), pct_change=-0.09471690569214508),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 1, 23), pct_change=-0.09396128822758532),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 23), pct_change=-0.09389873226029766),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 7, 26), pct_change=-0.0927529155720963),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 3, 17), pct_change=-0.09268255676406212),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 22), pct_change=-0.09259286145396695),
#  DailyChange(symbol='MSFT', date=datetime.date(2015, 1, 27), pct_change=-0.09253346490250869),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 4, 14), pct_change=-0.09210526540217512),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 12, 1), pct_change=-0.09206032892218918),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 7), pct_change=-0.09150192582025674),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 7, 24), pct_change=-0.09101509111728945),
#  DailyChange(symbol='FB', date=datetime.date(2012, 9, 24), pct_change=-0.09055117714124339),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 11, 30), pct_change=-0.08912645580052259),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 11, 22), pct_change=-0.08906861295863344),
#  DailyChange(symbol='FB', date=datetime.date(2012, 5, 22), pct_change=-0.08903905639256693),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 10, 3), pct_change=-0.08860757100892602),
#  DailyChange(symbol='MSFT', date=datetime.date(1998, 8, 31), pct_change=-0.08847980997624705),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 8, 28), pct_change=-0.08833363448882459),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 3, 18), pct_change=-0.08806157231229828),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 8, 31), pct_change=-0.08775149838408758),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 9, 29), pct_change=-0.08722627737226263),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 11, 15), pct_change=-0.08675807026542981),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 1, 6), pct_change=-0.08653857026626388),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 9, 17), pct_change=-0.08614523939194474),
#  DailyChange(symbol='MSFT', date=datetime.date(2004, 11, 15), pct_change=-0.0860860889584949),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 2, 1), pct_change=-0.08577005165743146),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 4, 12), pct_change=-0.08529558974358975),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 12, 18), pct_change=-0.0851064674814862),
#  DailyChange(symbol='FB', date=datetime.date(2012, 7, 26), pct_change=-0.0848670756646216),
#  DailyChange(symbol='GOOG', date=datetime.date(2006, 1, 20), pct_change=-0.08475199125557986),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 1, 4), pct_change=-0.08431054528426862),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 10, 7), pct_change=-0.08426939426811053),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 8, 11), pct_change=-0.08391595976979682),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 3, 12), pct_change=-0.08379272326350606),
#  DailyChange(symbol='GOOG', date=datetime.date(2012, 1, 20), pct_change=-0.08377503665697361),
#  DailyChange(symbol='GOOG', date=datetime.date(2004, 11, 5), pct_change=-0.08310774001592425),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 9, 8), pct_change=-0.08303358865541866),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 12, 12), pct_change=-0.08280293853698062),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 2), pct_change=-0.08266132394936487),
#  DailyChange(symbol='GOOG', date=datetime.date(2011, 4, 15), pct_change=-0.08264331845946171),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 7, 24), pct_change=-0.0825507857022999),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 12, 3), pct_change=-0.08238751652724863),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 5, 24), pct_change=-0.08227878609160189),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 10, 5), pct_change=-0.08199598796389174),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 3, 14), pct_change=-0.08196711679655),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 16), pct_change=-0.0815592044658413),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 4, 11), pct_change=-0.08142014693661237),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 8, 8), pct_change=-0.08137097555570683),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 9, 17), pct_change=-0.08110458210821192),
#  DailyChange(symbol='FB', date=datetime.date(2012, 7, 16), pct_change=-0.08040361589855527),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 3, 12), pct_change=-0.08024728486500199),
#  DailyChange(symbol='GOOG', date=datetime.date(2012, 10, 18), pct_change=-0.08006724873415683),
#  DailyChange(symbol='AAPL', date=datetime.date(2014, 1, 28), pct_change=-0.07992740854033031),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 3), pct_change=-0.07989698310127968),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 7, 19), pct_change=-0.07969435251043833),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 12, 1), pct_change=-0.0796240395461939),
#  DailyChange(symbol='MSFT', date=datetime.date(2003, 10, 24), pct_change=-0.07955721203735733),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 22), pct_change=-0.07938244160996488),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 4, 13), pct_change=-0.07913803550478926),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 6, 3), pct_change=-0.07913803550478926),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 8, 20), pct_change=-0.07883906186141121),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 1, 7), pct_change=-0.07878817498588131),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 9, 20), pct_change=-0.0787306883033344),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 5, 30), pct_change=-0.07871432101937237),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 12, 15), pct_change=-0.07843076970377094),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 22), pct_change=-0.07833903774233575),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 2, 9), pct_change=-0.07831363100591504),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 3, 9), pct_change=-0.07804820483009867),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 5, 2), pct_change=-0.07784466477809249),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 7, 10), pct_change=-0.07772211957177755),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 10, 18), pct_change=-0.0773813333333333),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 7, 3), pct_change=-0.0773813333333333),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 1, 17), pct_change=-0.07714303999999994),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 10, 17), pct_change=-0.07692307692307687),
#  DailyChange(symbol='AAPL', date=datetime.date(1992, 7, 17), pct_change=-0.07692276765278383),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 7, 9), pct_change=-0.07655438804076153),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 3, 5), pct_change=-0.0763901203687285),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 1, 4), pct_change=-0.07633511990799202),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 1, 28), pct_change=-0.0761363355785093),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 1, 7), pct_change=-0.07590720038323984),
#  DailyChange(symbol='GOOG', date=datetime.date(2010, 4, 16), pct_change=-0.07584417002362709),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 3, 28), pct_change=-0.07562992941176472),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 6, 30), pct_change=-0.07555472371334371),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 6, 7), pct_change=-0.07517064058401257),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 3, 30), pct_change=-0.07494267145164979),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 7, 1), pct_change=-0.07456246352634643),
#  DailyChange(symbol='MSFT', date=datetime.date(1992, 4, 20), pct_change=-0.07443658057193048),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 1, 8), pct_change=-0.07438014561847384),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 7, 7), pct_change=-0.07436004986087408),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 20), pct_change=-0.07391910739191077),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 24), pct_change=-0.073619737287827),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 11, 20), pct_change=-0.07359555470801693),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 7, 25), pct_change=-0.07354527363184071),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 7, 27), pct_change=-0.07348342042850531),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 16), pct_change=-0.07339392980372261),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 1, 15), pct_change=-0.0730769711242516),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 6, 25), pct_change=-0.07303405428601273),
#  DailyChange(symbol='MSFT', date=datetime.date(1991, 6, 19), pct_change=-0.07286981688752048),
#  DailyChange(symbol='MSFT', date=datetime.date(1995, 7, 19), pct_change=-0.07239271087959076),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 2, 27), pct_change=-0.07224344271118599),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 16), pct_change=-0.07211560983726073),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 1, 19), pct_change=-0.07208672086720869),
#  DailyChange(symbol='MSFT', date=datetime.date(2016, 4, 22), pct_change=-0.07171029171226773),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 11, 2), pct_change=-0.07153790988457198),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 11, 5), pct_change=-0.07142981818181826),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 12, 10), pct_change=-0.07142933333333323),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 10, 20), pct_change=-0.07142817391304346),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 21), pct_change=-0.07140924199733689),
#  DailyChange(symbol='GOOG', date=datetime.date(2006, 2, 1), pct_change=-0.0713724347545941),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 8, 27), pct_change=-0.07120704816486412),
#  DailyChange(symbol='GOOG', date=datetime.date(2006, 2, 28), pct_change=-0.07111022980200776),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 7, 28), pct_change=-0.07091349454511575),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 11, 7), pct_change=-0.07084796747967481),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 1, 20), pct_change=-0.07084502924512004),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 21), pct_change=-0.07060137211094442),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 11, 13), pct_change=-0.07051123734255382),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 2, 21), pct_change=-0.07047150276943337),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 7, 21), pct_change=-0.0703853631952327),
#  DailyChange(symbol='MSFT', date=datetime.date(1996, 1, 9), pct_change=-0.07028980869565216),
#  DailyChange(symbol='MSFT', date=datetime.date(2003, 1, 17), pct_change=-0.07028000253947608),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 1, 17), pct_change=-0.07024893600084403),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 10, 19), pct_change=-0.07023413626246511),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 11, 12), pct_change=-0.07020626696585597),
#  DailyChange(symbol='AAPL', date=datetime.date(1988, 1, 20), pct_change=-0.07017551903148178),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 4, 14), pct_change=-0.07017353277771177),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 11, 9), pct_change=-0.07003879180607342),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 9, 22), pct_change=-0.06997372429079618),
#  DailyChange(symbol='GOOG', date=datetime.date(2010, 7, 16), pct_change=-0.06965307063516679),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 9, 21), pct_change=-0.06956569648339861),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 6, 28), pct_change=-0.06947887508698758),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 8, 21), pct_change=-0.0693648504121337),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 4, 19), pct_change=-0.06936424792006957),
#  DailyChange(symbol='FB', date=datetime.date(2014, 3, 26), pct_change=-0.06934812866925766),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 11, 5), pct_change=-0.06928549543716556),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 11, 3), pct_change=-0.0691492530555734),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 3, 9), pct_change=-0.06905386081982845),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 5, 28), pct_change=-0.06896722187721094),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 7, 10), pct_change=-0.06872271311293932),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 7, 19), pct_change=-0.06847133757961787),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 7, 21), pct_change=-0.06846911132708444),
#  DailyChange(symbol='MSFT', date=datetime.date(1992, 11, 23), pct_change=-0.06842105263157894),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 7, 31), pct_change=-0.06837311309228589),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 3, 27), pct_change=-0.06827084499160607),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 7, 19), pct_change=-0.06818151735541567),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 10, 7), pct_change=-0.06788613453567993),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 9, 11), pct_change=-0.06785759999999996),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 11, 19), pct_change=-0.06778796800265185),
#  DailyChange(symbol='FB', date=datetime.date(2018, 3, 19), pct_change=-0.06769678681067126),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 7, 20), pct_change=-0.06763278750968504),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 7), pct_change=-0.06744279405861098),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 11, 5), pct_change=-0.06731342558210784),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 11, 20), pct_change=-0.06721525011918816),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 19), pct_change=-0.06699740482361527),
#  DailyChange(symbol='FB', date=datetime.date(2013, 10, 8), pct_change=-0.06690421615201902),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 10, 24), pct_change=-0.06690181392553418),
#  DailyChange(symbol='GOOG', date=datetime.date(2004, 11, 16), pct_change=-0.06669550740526609),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 6), pct_change=-0.06645510206685612),
#  DailyChange(symbol='AAPL', date=datetime.date(2018, 11, 2), pct_change=-0.06633068550836696),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 5), pct_change=-0.06613748148148146),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 2, 1), pct_change=-0.06595083226692222),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 12, 8), pct_change=-0.06578232807434359),
#  DailyChange(symbol='AAPL', date=datetime.date(2016, 1, 27), pct_change=-0.06570657197132845),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 12, 17), pct_change=-0.06570258897309644),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 11, 12), pct_change=-0.06569062386372027),
#  DailyChange(symbol='MSFT', date=datetime.date(1995, 7, 18), pct_change=-0.06536689908256887),
#  DailyChange(symbol='MSFT', date=datetime.date(1999, 4, 19), pct_change=-0.06493506493506496),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 10, 15), pct_change=-0.06490039659104518),
#  DailyChange(symbol='FB', date=datetime.date(2013, 11, 18), pct_change=-0.06488463843642689),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 10, 19), pct_change=-0.06484609936045305),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 4, 14), pct_change=-0.06466876971608837),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 1, 19), pct_change=-0.06457950684931502),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 11, 3), pct_change=-0.06451631550462489),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 7, 19), pct_change=-0.06442603921568624),
#  DailyChange(symbol='AAPL', date=datetime.date(2012, 12, 5), pct_change=-0.06435698302210913),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 11, 14), pct_change=-0.06428865549265184),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 12, 3), pct_change=-0.064235903163534),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 9, 17), pct_change=-0.06420880438008891),
#  DailyChange(symbol='AAPL', date=datetime.date(1992, 6, 16), pct_change=-0.06413264632895344),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 6), pct_change=-0.06406400615630081),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 10, 17), pct_change=-0.0639533142238724),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 17), pct_change=-0.0639533142238724),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 10, 1), pct_change=-0.06393401326520798),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 1, 11), pct_change=-0.06380496309773565),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 3, 2), pct_change=-0.06378896686690938),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 10, 13), pct_change=-0.06369384689042612),
#  DailyChange(symbol='MSFT', date=datetime.date(1996, 7, 23), pct_change=-0.06367425469728605),
#  DailyChange(symbol='FB', date=datetime.date(2012, 6, 1), pct_change=-0.0635135472972973),
#  DailyChange(symbol='AAPL', date=datetime.date(2006, 2, 6), pct_change=-0.06332647005354286),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 2, 8), pct_change=-0.06329268258104392),
#  DailyChange(symbol='MSFT', date=datetime.date(1993, 7, 30), pct_change=-0.06329113924050633),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 4, 12), pct_change=-0.06326186825722935),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 10, 16), pct_change=-0.06325552483928476),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 6, 16), pct_change=-0.06315796299167253),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 8, 3), pct_change=-0.06306302670239905),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 1, 11), pct_change=-0.06289464119173527),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 7), pct_change=-0.0628445424476296),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 10, 16), pct_change=-0.06279069767441858),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 19), pct_change=-0.06274509803921569),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 16), pct_change=-0.06273584609736582),
#  DailyChange(symbol='AAPL', date=datetime.date(2016, 4, 27), pct_change=-0.06257784499430474),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 4, 3), pct_change=-0.06252922070132283),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 1, 20), pct_change=-0.06240482305453188),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 1, 30), pct_change=-0.06223255805010475),
#  DailyChange(symbol='FB', date=datetime.date(2012, 7, 31), pct_change=-0.062203066954643615),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 8, 24), pct_change=-0.0621106086956521),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 2, 18), pct_change=-0.06209129411764713),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 7, 28), pct_change=-0.062068123851999335),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 1, 25), pct_change=-0.0620158605852128),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 5, 25), pct_change=-0.06196377502383221),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 4, 25), pct_change=-0.06194965603615277),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 1, 18), pct_change=-0.06192725971180946),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 5, 4), pct_change=-0.0617906783218245),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 11, 5), pct_change=-0.06162349929351896),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 15), pct_change=-0.06155629268292673),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 3, 12), pct_change=-0.06154132449281324),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 12, 3), pct_change=-0.06153798437858082),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 10, 13), pct_change=-0.06153798437858082),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 7, 24), pct_change=-0.06130830727047165),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 5, 3), pct_change=-0.06130145749507976),
#  DailyChange(symbol='AAPL', date=datetime.date(2015, 8, 21), pct_change=-0.06116289283332632),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 1, 23), pct_change=-0.06114481402621186),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 9, 2), pct_change=-0.060809972242150234),
#  DailyChange(symbol='FB', date=datetime.date(2014, 10, 29), pct_change=-0.060789849973623356),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 2, 27), pct_change=-0.06074790811402642),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 1, 18), pct_change=-0.06066198572659154),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 9), pct_change=-0.06060448362310056),
#  DailyChange(symbol='MSFT', date=datetime.date(1991, 7, 3), pct_change=-0.06055080389862111),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 11, 30), pct_change=-0.06049834829855616),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 7, 18), pct_change=-0.060319731104651164),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 1, 7), pct_change=-0.06021194605009639),
#  DailyChange(symbol='MSFT', date=datetime.date(1997, 7, 18), pct_change=-0.06020066889632103),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 6, 11), pct_change=-0.06003715384963915),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 1, 12), pct_change=-0.059973132075471725),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 10, 9), pct_change=-0.059958614748449435),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 7, 30), pct_change=-0.05990812903225806),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 4, 8), pct_change=-0.059881749506395465),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 12, 11), pct_change=-0.05987977768999597),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 11), pct_change=-0.05987977768999597),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 15), pct_change=-0.05975103734439835),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 19), pct_change=-0.05963333860795261),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 10, 22), pct_change=-0.05960140274496539),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 5, 20), pct_change=-0.05947433418079495),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 12, 30), pct_change=-0.05945927620163871),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 4, 1), pct_change=-0.05943358595931403),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 11, 6), pct_change=-0.0594050653846373),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 19), pct_change=-0.05914075615577863),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 6), pct_change=-0.05907174192170295),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 6, 5), pct_change=-0.05907171400595068),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 19), pct_change=-0.05900591304347824),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 15), pct_change=-0.05889698478757632),
#  DailyChange(symbol='MSFT', date=datetime.date(1989, 7, 25), pct_change=-0.05882490923449424),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 3, 23), pct_change=-0.058823764286490055),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 6, 15), pct_change=-0.05882352941176472),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 12, 9), pct_change=-0.0588232710496287),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 9, 10), pct_change=-0.05868536207543862),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 11, 8), pct_change=-0.058650573696349184),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 6, 29), pct_change=-0.05855349497851692),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 5, 20), pct_change=-0.05851048302395312),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 10, 14), pct_change=-0.05844072727272731),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 10, 27), pct_change=-0.0584306991340664),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 12, 10), pct_change=-0.0583333100000093),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 2), pct_change=-0.058252495805437565),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 3, 14), pct_change=-0.05821738457074954),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 11, 8), pct_change=-0.05813208740598941),
#  DailyChange(symbol='FB', date=datetime.date(2016, 2, 5), pct_change=-0.05810478881536418),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 10), pct_change=-0.05809128630705396),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 2, 28), pct_change=-0.058065117502415164),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 10, 25), pct_change=-0.05797157907950157),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 6, 11), pct_change=-0.05797008695652173),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 11, 19), pct_change=-0.0579651892016706),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 9, 20), pct_change=-0.0577315781597022),
#  DailyChange(symbol='AAPL', date=datetime.date(1992, 4, 7), pct_change=-0.05761316493082036),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 9, 15), pct_change=-0.05760712328718176),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 11, 9), pct_change=-0.057559613297758494),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 2, 4), pct_change=-0.05754256347943387),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 2, 26), pct_change=-0.05752897977252813),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 2), pct_change=-0.05752243965872694),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 2, 4), pct_change=-0.05747104734212283),
#  DailyChange(symbol='GOOG', date=datetime.date(2009, 3, 9), pct_change=-0.05729660786906965),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 7, 22), pct_change=-0.057290390623723986),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 3, 6), pct_change=-0.05721716514954489),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 2, 11), pct_change=-0.05719339622641506),
#  DailyChange(symbol='FB', date=datetime.date(2018, 11, 19), pct_change=-0.05719197346228033),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 11, 30), pct_change=-0.05714319999999995),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 7, 20), pct_change=-0.057143040000000034),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 10, 30), pct_change=-0.05714240000000004),
#  DailyChange(symbol='GOOG', date=datetime.date(2011, 8, 8), pct_change=-0.0570253461136222),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 2, 6), pct_change=-0.05689545454545464),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 5, 29), pct_change=-0.056871600188542315),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 8, 9), pct_change=-0.056861407986770085),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 1, 24), pct_change=-0.056857019138132237),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 1, 20), pct_change=-0.05676750450865131),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 3, 24), pct_change=-0.05673716050481048),
#  DailyChange(symbol='MSFT', date=datetime.date(2015, 8, 21), pct_change=-0.056723609286027044),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 5, 29), pct_change=-0.05667848096282624),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 10, 17), pct_change=-0.05663585009355365),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 4, 16), pct_change=-0.05660229832591601),
#  DailyChange(symbol='GOOG', date=datetime.date(2010, 1, 22), pct_change=-0.0565542747151595),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 14), pct_change=-0.05648152777777782),
#  DailyChange(symbol='GOOG', date=datetime.date(2009, 1, 20), pct_change=-0.056462026848706826),
#  DailyChange(symbol='FB', date=datetime.date(2016, 11, 3), pct_change=-0.056381207146044),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 3, 19), pct_change=-0.0563375838126855),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 12, 11), pct_change=-0.056283354862525226),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 1, 24), pct_change=-0.05627733333333329),
#  DailyChange(symbol='AAPL', date=datetime.date(1992, 7, 2), pct_change=-0.05612228571428568),
#  DailyChange(symbol='AAPL', date=datetime.date(2006, 2, 9), pct_change=-0.05609654120040697),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 5, 15), pct_change=-0.05607484950651953),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 14), pct_change=-0.05604939082035032),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 9, 14), pct_change=-0.056047569930612884),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 11, 14), pct_change=-0.05600004705882344),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 9, 22), pct_change=-0.05594368350480572),
#  DailyChange(symbol='AAPL', date=datetime.date(2011, 10, 19), pct_change=-0.05593977122015914),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 9, 27), pct_change=-0.05582279376128629),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 1, 7), pct_change=-0.055794296745364846),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 4, 30), pct_change=-0.05579378923905842),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 1, 15), pct_change=-0.055784807219373844),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 11, 10), pct_change=-0.05572746615033386),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 12, 28), pct_change=-0.05571820923445192),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 10, 29), pct_change=-0.05570382079394365),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 1, 16), pct_change=-0.05560813515632057),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 2, 28), pct_change=-0.055556131687072074),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 6, 13), pct_change=-0.05555555555555558),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 10, 10), pct_change=-0.05555542857142848),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 9, 25), pct_change=-0.05531914893617018),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 9, 27), pct_change=-0.05527514880818374),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 7, 25), pct_change=-0.05526317243767698),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 21), pct_change=-0.05501610254919509),
#  DailyChange(symbol='AAPL', date=datetime.date(2013, 4, 17), pct_change=-0.05499250058669991),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 8, 30), pct_change=-0.0549377925311203),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 14), pct_change=-0.05490196078431364),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 10, 20), pct_change=-0.054794100206279506),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 7), pct_change=-0.05474457116788323),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 9, 8), pct_change=-0.054698933938537975),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 9, 17), pct_change=-0.05463639861485181),
#  DailyChange(symbol='AAPL', date=datetime.date(2011, 8, 8), pct_change=-0.05462770865679212),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 4, 26), pct_change=-0.054554314166075146),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 7, 19), pct_change=-0.054545454545454564),
#  DailyChange(symbol='MSFT', date=datetime.date(1998, 10, 1), pct_change=-0.054514480408858645),
#  DailyChange(symbol='FB', date=datetime.date(2013, 2, 4), pct_change=-0.05449038008745377),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 1, 15), pct_change=-0.05448042073295145),
#  DailyChange(symbol='AAPL', date=datetime.date(2013, 9, 11), pct_change=-0.05444366621066565),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 9, 7), pct_change=-0.05442133333333332),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 1, 30), pct_change=-0.05439358778740422),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 11, 6), pct_change=-0.05434787137681141),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 3, 13), pct_change=-0.054346820415179464),
#  DailyChange(symbol='MSFT', date=datetime.date(2018, 10, 10), pct_change=-0.05433812481136424),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 1, 27), pct_change=-0.054299174545513584),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 3, 25), pct_change=-0.054187034482758634),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 3, 25), pct_change=-0.054151399757562446),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 1, 9), pct_change=-0.054151399757562446),
#  DailyChange(symbol='FB', date=datetime.date(2018, 10, 24), pct_change=-0.05408385293143225),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 1, 9), pct_change=-0.054054599464014697),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 10, 13), pct_change=-0.054017293708020664),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 2, 9), pct_change=-0.0540079590676521),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 6, 27), pct_change=-0.053990301747935954),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 31), pct_change=-0.0539550026191723),
#  DailyChange(symbol='MSFT', date=datetime.date(2011, 8, 10), pct_change=-0.05394835809225951),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 1, 18), pct_change=-0.05382195820211855),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 2, 3), pct_change=-0.05381335027753886),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 11, 10), pct_change=-0.05379687165506264),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 20), pct_change=-0.05365732130798606),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 4, 12), pct_change=-0.05365126676602083),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 10, 6), pct_change=-0.0535714285714286),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 10, 10), pct_change=-0.053571000000000035),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 2, 19), pct_change=-0.053556731919938705),
#  DailyChange(symbol='GOOG', date=datetime.date(2009, 2, 10), pct_change=-0.05348895160603617),
#  DailyChange(symbol='MSFT', date=datetime.date(2018, 10, 24), pct_change=-0.05346899266362615),
#  DailyChange(symbol='GOOG', date=datetime.date(2007, 11, 8), pct_change=-0.053346817764747034),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 6), pct_change=-0.05323590814196244),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 5, 6), pct_change=-0.0531910774104879),
#  DailyChange(symbol='GOOG', date=datetime.date(2016, 4, 22), pct_change=-0.05317858919609175),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 7, 7), pct_change=-0.053155720930232575),
#  DailyChange(symbol='GOOG', date=datetime.date(2015, 8, 21), pct_change=-0.053105199352552646),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 3, 26), pct_change=-0.05304356982987557),
#  DailyChange(symbol='GOOG', date=datetime.date(2011, 8, 18), pct_change=-0.05302446095388402),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 2, 16), pct_change=-0.052959590687184366),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 10, 26), pct_change=-0.05294046339046665),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 10, 3), pct_change=-0.05291022222222219),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 4, 7), pct_change=-0.05289625034095724),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 3, 3), pct_change=-0.052810495303955096),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 3, 5), pct_change=-0.05272958729965338),
#  DailyChange(symbol='MSFT', date=datetime.date(1986, 11, 18), pct_change=-0.0526347700723534),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 1, 30), pct_change=-0.0526324814905319),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 6, 3), pct_change=-0.05263140972052527),
#  DailyChange(symbol='MSFT', date=datetime.date(1997, 9, 15), pct_change=-0.05256003472413129),
#  DailyChange(symbol='MSFT', date=datetime.date(2009, 2, 17), pct_change=-0.05238344683080143),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 10, 20), pct_change=-0.052327383448502185),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 11, 23), pct_change=-0.052327383448502185),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 9, 5), pct_change=-0.05220898398418661),
#  DailyChange(symbol='AAPL', date=datetime.date(1980, 12, 15), pct_change=-0.05217445504710816),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 2, 9), pct_change=-0.05217445504710816),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 11, 28), pct_change=-0.05216622458001763),
#  DailyChange(symbol='FB', date=datetime.date(2014, 4, 10), pct_change=-0.05207498798269505),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 8, 23), pct_change=-0.052044646812536066),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 1, 11), pct_change=-0.052044603474247886),
#  DailyChange(symbol='AAPL', date=datetime.date(2015, 8, 11), pct_change=-0.05203811349784404),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 8, 17), pct_change=-0.05194836363636357),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 3, 8), pct_change=-0.05192984673848311),
#  DailyChange(symbol='FB', date=datetime.date(2014, 4, 25), pct_change=-0.05191391575347315),
#  DailyChange(symbol='GOOG', date=datetime.date(2007, 7, 20), pct_change=-0.05189665244913677),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 5, 9), pct_change=-0.05184653258699168),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 9, 5), pct_change=-0.05181364589656301),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 2), pct_change=-0.05178488251092639),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 2, 27), pct_change=-0.051745586899884954),
#  DailyChange(symbol='FB', date=datetime.date(2013, 1, 29), pct_change=-0.05174006616137783),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 5, 21), pct_change=-0.05173831432996645),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 8, 3), pct_change=-0.05172406024571774),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 4, 22), pct_change=-0.051723738406548536),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 9, 3), pct_change=-0.05172338327415782),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 6, 16), pct_change=-0.05168609005903524),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 8, 19), pct_change=-0.051643560316460446),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 10, 2), pct_change=-0.05156415309101969),
#  DailyChange(symbol='FB', date=datetime.date(2014, 4, 3), pct_change=-0.05149870772482934),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 6, 26), pct_change=-0.05146848664295922),
#  DailyChange(symbol='MSFT', date=datetime.date(1999, 7, 20), pct_change=-0.0514612452350699),
#  DailyChange(symbol='MSFT', date=datetime.date(1995, 5, 30), pct_change=-0.05142857142857138),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 11, 16), pct_change=-0.051383665172152426),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 7, 31), pct_change=-0.05136966072427207),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 4, 2), pct_change=-0.05134156835569492),
#  DailyChange(symbol='MSFT', date=datetime.date(2018, 2, 8), pct_change=-0.051333544790385544),
#  DailyChange(symbol='AAPL', date=datetime.date(2007, 9, 5), pct_change=-0.05133181116354313),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 8, 6), pct_change=-0.051290216547294376),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 4, 15), pct_change=-0.05126138087121257),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 4, 10), pct_change=-0.051233307058316635),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 1, 11), pct_change=-0.05115077865789608),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 1, 5), pct_change=-0.051135654958420096),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 9, 29), pct_change=-0.051094902445524615),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 10, 29), pct_change=-0.051020571428571415),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 2, 6), pct_change=-0.05101942857142849),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 8, 24), pct_change=-0.0509789246586414),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 7, 8), pct_change=-0.05095570935934579),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 1, 21), pct_change=-0.05084745762711862),
#  DailyChange(symbol='MSFT', date=datetime.date(1999, 9, 23), pct_change=-0.05074821080026026),
#  DailyChange(symbol='FB', date=datetime.date(2012, 12, 14), pct_change=-0.05063742917847014),
#  DailyChange(symbol='GOOG', date=datetime.date(2018, 10, 10), pct_change=-0.05057864959453395),
#  DailyChange(symbol='MSFT', date=datetime.date(1987, 6, 10), pct_change=-0.05045815806717535),
#  DailyChange(symbol='GOOG', date=datetime.date(2018, 2, 5), pct_change=-0.050454153960878156),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 3, 17), pct_change=-0.05042070588235292),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 6, 12), pct_change=-0.05042007843137253),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 9, 27), pct_change=-0.050419764705882386),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 8), pct_change=-0.0504031661680483),
#  DailyChange(symbol='AAPL', date=datetime.date(2018, 11, 12), pct_change=-0.05037415244107135),
#  DailyChange(symbol='GOOG', date=datetime.date(2004, 10, 20), pct_change=-0.05035822672627066),
#  DailyChange(symbol='GOOG', date=datetime.date(2018, 12, 4), pct_change=-0.0502608436917964),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 2, 9), pct_change=-0.050200803212851364),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 1, 20), pct_change=-0.05016397242205861),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 7, 6), pct_change=-0.05002206553978461),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 12, 8), pct_change=-0.050000124444459226),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 12, 6), pct_change=-0.049999906666674976),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 6, 8), pct_change=-0.04999984727274953),
#  DailyChange(symbol='FB', date=datetime.date(2015, 8, 20), pct_change=-0.04983737382934372),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 3, 21), pct_change=-0.04982206405693945),
#  DailyChange(symbol='FB', date=datetime.date(2015, 8, 21), pct_change=-0.049690813818260016),
#  DailyChange(symbol='AAPL', date=datetime.date(2010, 1, 22), pct_change=-0.0495986699091332),
#  DailyChange(symbol='MSFT', date=datetime.date(1988, 8, 22), pct_change=-0.04950469640199151),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 7, 2), pct_change=-0.0495018762807945),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 9, 24), pct_change=-0.04948746772291868),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 5, 21), pct_change=-0.04944691994492367),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 11, 10), pct_change=-0.04938271604938271),
# ...
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 5, 10), pct_change=-0.040867392899699206),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 1, 30), pct_change=-0.04085785364051442),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 6, 5), pct_change=-0.04084988235294129),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 11, 12), pct_change=-0.04081676190476191),
#  DailyChange(symbol='AAPL', date=datetime.date(1989, 6, 5), pct_change=-0.040816571428571424),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 5, 17), pct_change=-0.040816571428571424),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 17), pct_change=-0.040804291050015484),
#  DailyChange(symbol='GOOG', date=datetime.date(2005, 2, 7), pct_change=-0.04076138354763281),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 31), pct_change=-0.0406851810163108),
#  DailyChange(symbol='MSFT', date=datetime.date(2010, 5, 26), pct_change=-0.04065976217874945),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 11, 6), pct_change=-0.04065827646991016),
#  DailyChange(symbol='MSFT', date=datetime.date(1996, 12, 16), pct_change=-0.04062500000000002),
#  DailyChange(symbol='FB', date=datetime.date(2013, 9, 16), pct_change=-0.040622951012797226),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 7, 5), pct_change=-0.04060882537545596),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 10, 2), pct_change=-0.04060882537545596),
#  DailyChange(symbol='MSFT', date=datetime.date(1986, 12, 29), pct_change=-0.04060652487909855),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 11, 2), pct_change=-0.04057969885318524),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 10, 6), pct_change=-0.040577899954108876),
#  DailyChange(symbol='GOOG', date=datetime.date(2012, 4, 13), pct_change=-0.040567705202405935),
#  DailyChange(symbol='GOOG', date=datetime.date(2005, 1, 4), pct_change=-0.040501233946841464),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 3, 17), pct_change=-0.04049273695692812),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 12, 27), pct_change=-0.04045904844919246),
#  DailyChange(symbol='MSFT', date=datetime.date(2000, 12, 28), pct_change=-0.04037685060565277),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 12, 1), pct_change=-0.04035820784584687),
#  DailyChange(symbol='FB', date=datetime.date(2013, 2, 1), pct_change=-0.040348612007746976),
#  DailyChange(symbol='MSFT', date=datetime.date(1991, 6, 24), pct_change=-0.040342529850951325),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 7, 13), pct_change=-0.04033973810071312),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 1, 26), pct_change=-0.040292923076923115),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 1, 5), pct_change=-0.040292923076923115),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 3, 15), pct_change=-0.0402754078974038),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 7, 15), pct_change=-0.040268138552283395),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 11, 19), pct_change=-0.040262494933544835),
#  DailyChange(symbol='GOOG', date=datetime.date(2014, 2, 3), pct_change=-0.04025514121318141),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 6, 26), pct_change=-0.0402541026938843),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 10, 10), pct_change=-0.040229896155373646),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 12, 31), pct_change=-0.04022987026027758),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 2), pct_change=-0.04022979119874481),
#  DailyChange(symbol='FB', date=datetime.date(2012, 12, 21), pct_change=-0.04020471344281018),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 10, 3), pct_change=-0.04020123976663481),
#  DailyChange(symbol='MSFT', date=datetime.date(1995, 7, 28), pct_change=-0.040155357512953405),
#  DailyChange(symbol='GOOG', date=datetime.date(2005, 1, 24), pct_change=-0.04015299844427034),
#  DailyChange(symbol='GOOG', date=datetime.date(2006, 11, 27), pct_change=-0.040099000612460745),
#  DailyChange(symbol='MSFT', date=datetime.date(2016, 6, 24), pct_change=-0.040069312271238666),
#  DailyChange(symbol='MSFT', date=datetime.date(2012, 11, 13), pct_change=-0.04004248901638874),
#  DailyChange(symbol='MSFT', date=datetime.date(2018, 12, 7), pct_change=-0.04002199761842673),
#  DailyChange(symbol='MSFT', date=datetime.date(2010, 5, 20), pct_change=-0.040014128895184076),
#  DailyChange(symbol='MSFT', date=datetime.date(1992, 6, 11), pct_change=-0.040000000000000036),
#  DailyChange(symbol='MSFT', date=datetime.date(1999, 2, 17), pct_change=-0.040000000000000036),
#  DailyChange(symbol='MSFT', date=datetime.date(1986, 7, 7), pct_change=-0.0399974195213213),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 10, 30), pct_change=-0.03997957361781013),
#  DailyChange(symbol='FB', date=datetime.date(2017, 11, 29), pct_change=-0.03996268545074744),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 10, 1), pct_change=-0.039943664966182846),
#  DailyChange(symbol='AAPL', date=datetime.date(2001, 7, 19), pct_change=-0.03992323232323247),
#  DailyChange(symbol='MSFT', date=datetime.date(2016, 1, 15), pct_change=-0.03991713349807691),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 3, 6), pct_change=-0.03984681629206732),
#  DailyChange(symbol='MSFT', date=datetime.date(2010, 6, 4), pct_change=-0.0398361861565083),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 4, 6), pct_change=-0.03978910067114094),
#  DailyChange(symbol='AAPL', date=datetime.date(1983, 2, 7), pct_change=-0.03977274173554246),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 5, 12), pct_change=-0.03974683954619129),
#  DailyChange(symbol='MSFT', date=datetime.date(2002, 5, 10), pct_change=-0.039716003058941074),
#  DailyChange(symbol='MSFT', date=datetime.date(2014, 10, 10), pct_change=-0.03969463640979887),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 9, 24), pct_change=-0.039682666666666644),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 4, 15), pct_change=-0.039682666666666644),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 2, 4), pct_change=-0.03967820556198021),
#  DailyChange(symbol='FB', date=datetime.date(2013, 12, 27), pct_change=-0.039667434609388486),
#  DailyChange(symbol='GOOG', date=datetime.date(2006, 5, 11), pct_change=-0.039654580048123056),
#  DailyChange(symbol='AAPL', date=datetime.date(2018, 11, 19), pct_change=-0.03963208825314979),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 5, 13), pct_change=-0.039623870123390637),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 12, 14), pct_change=-0.039610587905684724),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 9, 14), pct_change=-0.03960473992721103),
#  DailyChange(symbol='MSFT', date=datetime.date(1992, 6, 16), pct_change=-0.03960395203084843),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 4, 13), pct_change=-0.03958645075509648),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 10, 16), pct_change=-0.03957770970682184),
#  DailyChange(symbol='MSFT', date=datetime.date(1986, 11, 10), pct_change=-0.03955195709618209),
#  DailyChange(symbol='FB', date=datetime.date(2016, 1, 13), pct_change=-0.0395491685755508),
#  DailyChange(symbol='AAPL', date=datetime.date(2009, 2, 19), pct_change=-0.03952526394088218),
#  DailyChange(symbol='FB', date=datetime.date(2014, 10, 10), pct_change=-0.03952048270212183),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 9, 9), pct_change=-0.0395136542337613),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 9, 13), pct_change=-0.03950640363355595),
#  DailyChange(symbol='MSFT', date=datetime.date(2003, 4, 9), pct_change=-0.039483971853010114),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 7, 16), pct_change=-0.03942720242530118),
#  DailyChange(symbol='GOOG', date=datetime.date(2007, 2, 1), pct_change=-0.03938185536114458),
#  DailyChange(symbol='GOOG', date=datetime.date(2011, 8, 4), pct_change=-0.03933988535440358),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 7, 30), pct_change=-0.03932583562681602),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 12, 19), pct_change=-0.039302685455267494),
#  DailyChange(symbol='MSFT', date=datetime.date(2001, 12, 20), pct_change=-0.03928617180273919),
#  DailyChange(symbol='GOOG', date=datetime.date(2010, 5, 20), pct_change=-0.03927752816856567),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 5, 14), pct_change=-0.039242728640590085),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 5, 22), pct_change=-0.03917006451612903),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 4, 13), pct_change=-0.039145802510076044),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 8, 5), pct_change=-0.03913267326732672),
#  DailyChange(symbol='AAPL', date=datetime.date(1995, 8, 28), pct_change=-0.03910615224244063),
#  DailyChange(symbol='GOOG', date=datetime.date(2018, 11, 19), pct_change=-0.03908655794295346),
#  DailyChange(symbol='GOOG', date=datetime.date(2008, 2, 19), pct_change=-0.03906427522850697),
#  DailyChange(symbol='MSFT', date=datetime.date(2015, 9, 1), pct_change=-0.03906250000000011),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 3, 9), pct_change=-0.039033452605685914),
#  DailyChange(symbol='FB', date=datetime.date(2012, 11, 9), pct_change=-0.03901955977988991),
#  DailyChange(symbol='MSFT', date=datetime.date(1993, 11, 22), pct_change=-0.03900146411247074),
#  DailyChange(symbol='GOOG', date=datetime.date(2004, 8, 30), pct_change=-0.03900143876504347),
#  DailyChange(symbol='AAPL', date=datetime.date(2002, 7, 8), pct_change=-0.03895348098830764),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 8, 16), pct_change=-0.038910261654195866),
#  DailyChange(symbol='AAPL', date=datetime.date(1981, 3, 11), pct_change=-0.03888886123458757),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 4, 22), pct_change=-0.03888886123458757),
#  DailyChange(symbol='AAPL', date=datetime.date(1997, 4, 30), pct_change=-0.038868379726957336),
#  DailyChange(symbol='AAPL', date=datetime.date(1982, 8, 5), pct_change=-0.03883676727081342),
#  DailyChange(symbol='MSFT', date=datetime.date(1993, 8, 19), pct_change=-0.03883494341282723),
#  DailyChange(symbol='AAPL', date=datetime.date(1999, 12, 13), pct_change=-0.03883491714581555),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 11, 8), pct_change=-0.03883467697212606),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 12, 3), pct_change=-0.03879767025909131),
#  DailyChange(symbol='MSFT', date=datetime.date(2011, 1, 28), pct_change=-0.03879462976118353),
#  DailyChange(symbol='AAPL', date=datetime.date(2017, 6, 9), pct_change=-0.03877675208798137),
#  DailyChange(symbol='AAPL', date=datetime.date(2008, 7, 18), pct_change=-0.038763728501359895),
#  DailyChange(symbol='FB', date=datetime.date(2014, 7, 8), pct_change=-0.03875023680884915),
#  DailyChange(symbol='AAPL', date=datetime.date(2011, 8, 4), pct_change=-0.03871921665904776),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 11, 13), pct_change=-0.03871007833494344),
#  DailyChange(symbol='MSFT', date=datetime.date(1991, 7, 10), pct_change=-0.0386743730654151),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 10, 30), pct_change=-0.038647039790846716),
#  DailyChange(symbol='AAPL', date=datetime.date(2006, 2, 13), pct_change=-0.03862718878702087),
#  DailyChange(symbol='AAPL', date=datetime.date(1990, 10, 9), pct_change=-0.038627005544238036),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 7, 8), pct_change=-0.03859714757742139),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 9, 26), pct_change=-0.038551547078331305),
#  DailyChange(symbol='MSFT', date=datetime.date(1998, 7, 28), pct_change=-0.03854389721627405),
#  DailyChange(symbol='AAPL', date=datetime.date(2003, 9, 15), pct_change=-0.03852787878787867),
#  DailyChange(symbol='MSFT', date=datetime.date(2003, 9, 24), pct_change=-0.03851354729729739),
#  DailyChange(symbol='FB', date=datetime.date(2014, 1, 24), pct_change=-0.03849549640657779),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 7, 26), pct_change=-0.038462080688299594),
#  DailyChange(symbol='AAPL', date=datetime.date(1987, 3, 30), pct_change=-0.03846167100594977),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 7, 16), pct_change=-0.038461538461538436),
#  DailyChange(symbol='MSFT', date=datetime.date(1994, 2, 4), pct_change=-0.038461349112426046),
#  DailyChange(symbol='FB', date=datetime.date(2015, 9, 28), pct_change=-0.03837445418910601),
#  DailyChange(symbol='AAPL', date=datetime.date(1994, 7, 20), pct_change=-0.03837429551221183),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 6, 23), pct_change=-0.038372239004856645),
#  DailyChange(symbol='AAPL', date=datetime.date(1998, 10, 20), pct_change=-0.038333858488776795),
#  DailyChange(symbol='MSFT', date=datetime.date(2015, 1, 30), pct_change=-0.03832411513087919),
#  DailyChange(symbol='GOOG', date=datetime.date(2018, 3, 22), pct_change=-0.038317733213929395),
#  DailyChange(symbol='FB', date=datetime.date(2012, 6, 5), pct_change=-0.038289925650557666),
#  DailyChange(symbol='MSFT', date=datetime.date(1999, 7, 22), pct_change=-0.03828382838283828),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 3, 19), pct_change=-0.03825137949775026),
#  DailyChange(symbol='MSFT', date=datetime.date(2008, 12, 4), pct_change=-0.0382486140790832),
#  DailyChange(symbol='AAPL', date=datetime.date(1988, 3, 24), pct_change=-0.03823548595157511),
#  DailyChange(symbol='FB', date=datetime.date(2012, 8, 1), pct_change=-0.038231231608992666),
#  DailyChange(symbol='MSFT', date=datetime.date(1993, 2, 4), pct_change=-0.038189620305324246),
#  DailyChange(symbol='MSFT', date=datetime.date(1986, 6, 12), pct_change=-0.03816558941212678),
#  DailyChange(symbol='MSFT', date=datetime.date(1998, 3, 9), pct_change=-0.03814264652567978),
#  DailyChange(symbol='AAPL', date=datetime.date(1992, 4, 20), pct_change=-0.03813552283826971),
#  DailyChange(symbol='AAPL', date=datetime.date(2014, 9, 25), pct_change=-0.038132648648648626),
#  DailyChange(symbol='MSFT', date=datetime.date(1991, 3, 6), pct_change=-0.038116738160842156),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 10, 25), pct_change=-0.03809493333333336),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 9, 13), pct_change=-0.03809493333333336),
#  DailyChange(symbol='AAPL', date=datetime.date(2004, 12, 2), pct_change=-0.038058768607205584),
#  DailyChange(symbol='AAPL', date=datetime.date(2010, 5, 6), pct_change=-0.03804840032813783),
#  DailyChange(symbol='AAPL', date=datetime.date(2000, 5, 4), pct_change=-0.03802281368821292),
#  DailyChange(symbol='AAPL', date=datetime.date(2005, 4, 13), pct_change=-0.03797459423049632),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 7, 1), pct_change=-0.03797438743785064),
#  DailyChange(symbol='AAPL', date=datetime.date(1984, 8, 8), pct_change=-0.03797413320529741),
#  DailyChange(symbol='GOOG', date=datetime.date(2016, 6, 24), pct_change=-0.037970028908273834),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 7, 15), pct_change=-0.03793017683653099),
#  DailyChange(symbol='AAPL', date=datetime.date(1986, 12, 12), pct_change=-0.037901061224489774),
#  DailyChange(symbol='MSFT', date=datetime.date(1996, 1, 15), pct_change=-0.03790087463556846),
#  DailyChange(symbol='GOOG', date=datetime.date(2011, 10, 3), pct_change=-0.03790002334556186),
#  DailyChange(symbol='AAPL', date=datetime.date(1985, 9, 25), pct_change=-0.03787973920982335),
#  DailyChange(symbol='AAPL', date=datetime.date(1996, 12, 19), pct_change=-0.037837831292915625),
#  DailyChange(symbol='FB', date=datetime.date(2012, 10, 31), pct_change=-0.03783044494847554),
#  DailyChange(symbol='AAPL', date=datetime.date(2011, 8, 18), pct_change=-0.03782461846467644),
#  DailyChange(symbol='AAPL', date=datetime.date(1993, 2, 5), pct_change=-0.03781505882352931),
#  DailyChange(symbol='AAPL', date=datetime.date(2006, 6, 12), pct_change=-0.037812171468807665),
#  DailyChange(symbol='AAPL', date=datetime.date(1991, 4, 3), pct_change=-0.03780058147635257),
#  DailyChange(symbol='MSFT', date=datetime.date(1990, 8, 29), pct_change=-0.03777322779823755),
#  ...]

# %%
changes_by_month: List[DailyChange] = {month: [] for month in range(1, 13)}
for change in all_changes:
    changes_by_month[change.date.month].append(change)

avg_daily_change = {
    month: sum(change.pct_change for change in changes) / len(changes) 
    for month, changes in changes_by_month.items()
}

avg_daily_change
# Out:
# {1: 0.0021865911307884013,
#  2: 0.00014320928359588448,
#  3: 0.0009950657322022312,
#  4: 0.0017246603289960414,
#  5: 0.001045801424244935,
#  6: -0.00038890680439638084,
#  7: 0.0008653144845121465,
#  8: 0.0012329314091353012,
#  9: -4.63670330797049e-06,
#  10: 0.002905423893850083,
#  11: 0.0008081709427041247,
#  12: 0.0009192394682663616}

# %%
# this is always useful: sort the dict using .items and key=lambda
best_month = sorted(avg_daily_change.items(),key=lambda x: x[1], reverse=True)
best_month
# Out:
# [(10, 0.002905423893850083),
#  (1, 0.0021865911307884013),
#  (4, 0.0017246603289960414),
#  (8, 0.0012329314091353012),
#  (5, 0.001045801424244935),
#  (3, 0.0009950657322022312),
#  (12, 0.0009192394682663616),
#  (7, 0.0008653144845121465),
#  (11, 0.0008081709427041247),
#  (2, 0.00014320928359588448),
#  (9, -4.63670330797049e-06),
#  (6, -0.00038890680439638084)]

# %%
best_one = max(all_changes, key=lambda x: x.pct_change)
best_one
# Out:
# DailyChange(symbol='AAPL', date=datetime.date(1997, 8, 6), pct_change=0.33227854830957937)

# %% [markdown]
# ## Vectors
#
# This is an interesting way to get rid of units: everything is normalised so that each dimension has mean 0 and standard deviation 1.
#
# Normalizing the data can help improve the performance and convergence of some machine learning algorithms, as well as make it easier to compare the importance of different features.

# %%
from typing import Tuple

from scratch.linear_algebra import vector_mean
from scratch.statistics import standard_deviation

def scale(data: List[Vector]) -> Tuple[Vector, Vector]:
    """returns the means and standard deviations for each position"""
    dim = len(data[0])

    means = vector_mean(data)
    stdevs = [standard_deviation([vector[i] for vector in data])
              for i in range(dim)]

    return means, stdevs

vectors = [[-3, -1, 1], [-1, 0, 1], [1, 1, 1]]
means, stdevs = scale(vectors)

means, stdevs
# Out:
# ([-1.0, 0.0, 1.0], [2.0, 1.0, 0.0])

# %% [markdown]
# We use the above to create a new dataset. This type of data preprocessing is useful to visualize the data, or when an algorithm requires input features to be within a specific range.
#
# Rescaling the data can be particularly helpful for algorithms that are sensitive to the scale of input features, such as *gradient descent-based methods* or distance-based algorithms like *k-Nearest Neighbors*.

# %%
def rescale(data: List[Vector]) -> List[Vector]:
    """
    Rescales the input data so that each position has
    mean 0 and standard deviation 1. (Leaves a position
    as is if its standard deviation is 0.)
    """
    dim = len(data[0])
    means, stdevs = scale(data)

    # Make a copy of each vector
    rescaled = [v[:] for v in data]

    for v in rescaled:
        for i in range(dim):
            if stdevs[i] > 0:
                v[i] = (v[i] - means[i]) / stdevs[i]

    return rescaled

means, stdevs = scale(rescale(vectors))

means, stdevs
# Out:
# ([0.0, 0.0, 1.0], [1.0, 1.0, 0.0])

# %% [markdown]
# ## side note: tqdm

# %%
import tqdm
import random

for i in tqdm.tqdm(range(100)):
    [random.random() for _ in range(100000)]
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 80.89it/s]

# %%
with tqdm.trange(100) as t:
    for i in t:
        t.set_description('Processing %i' % i)
# Out:
# Processing 99: 100%|██████████| 100/100 [00:00<00:00, 1496.53it/s]

# %%
# this one shows all the primes it processes
from typing import List

def primes_up_to(n: int) -> List[int]:
    primes = [2]

    with tqdm.trange(3, n) as t:
        for i in t:
            # i is prime if no smaller prime divides it.
            i_is_prime = not any(i % p == 0 for p in primes)
            if i_is_prime:
                primes.append(i)

            t.set_description(f"{len(primes)} primes")

    return primes

my_primes = primes_up_to(100_000)

# %% [markdown]
# ## Some probability distributions
#
# Just to show how looking at similar datasets doesn't tell us much. A visualisation is a great first step.

# %%
import matplotlib as plt

# remove buffered variables
plt.gca().clear()
plt.close()

import random
from scratch.probability import inverse_normal_cdf

random.seed(0)

# uniform between -100 and 100
uniform = [200 * random.random() - 100 for _ in range(10000)]

# normal distribution with mean 0, standard deviation 57
normal = [57 * inverse_normal_cdf(random.random())
            for _ in range(10000)]

plot_histogram(uniform, 10, "Uniform Histogram")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 import matplotlib as plt
#       3 # remove buffered variables
# ----> 4 plt.gca().clear()
#       5 plt.close()
#       7 import random
#
# File c:\Users\johan\.conda\envs\joh_env\lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'gca'

# %%
plt.savefig('im/working_histogram_uniform.png')
plt.gca().clear()
plt.close()

plot_histogram(normal, 10, "Normal Histogram")

# %%
plt.savefig('im/working_histogram_normal.png')
plt.gca().clear()    # gca = get current axes

# %% [markdown]
# Correlations are also important. On a scatterplot (in book but not here) we can see how they follow opposite directions.

# %%
from scratch.statistics import correlation

print(correlation(xs, ys1))      # about 0.9
print(correlation(xs, ys2))      # about -0.9
# Out:
# 0.8933366949950308
# -0.8990210993559374

# %%
normal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 normal
#
# NameError: name 'normal' is not defined
