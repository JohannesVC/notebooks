# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.randn(1000,1))

plt.hist(df, bins=20, 
         density=True # gives it a total of 1
         )
# Out:
# (array([0.00310661, 0.        , 0.01863967, 0.01553306, 0.06834546,
#         0.12115786, 0.11183802, 0.17397026, 0.29823473, 0.27959506,
#         0.3696868 , 0.38832647, 0.3448339 , 0.38211324, 0.20503638,
#         0.15533059, 0.09009174, 0.0528124 , 0.01242645, 0.01553306]),
#  array([-3.54042579e+00, -3.21853169e+00, -2.89663758e+00, -2.57474348e+00,
#         -2.25284938e+00, -1.93095527e+00, -1.60906117e+00, -1.28716707e+00,
#         -9.65272965e-01, -6.43378862e-01, -3.21484759e-01,  4.09343589e-04,
#          3.22303446e-01,  6.44197549e-01,  9.66091652e-01,  1.28798576e+00,
#          1.60987986e+00,  1.93177396e+00,  2.25366806e+00,  2.57556217e+00,
#          2.89745627e+00]),
#  <BarContainer object of 20 artists>)

# %%
import seaborn as sns

sns.displot(df, kde=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.std()
# Out:
# 0    0.969399
# dtype: float64

# %%
np.random.choice(['A', 'B'], 100)
# Out:
# array(['B', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'A',
#        'A', 'A', 'A', 'A', 'B', 'B', 'A', 'B', 'B', 'A', 'B', 'A', 'A',
#        'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B', 'A', 'A', 'B', 'A', 'A',
#        'A', 'A', 'B', 'A', 'A', 'A', 'A', 'B', 'B', 'A', 'B', 'A', 'B',
#        'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'A', 'B', 'B', 'B',
#        'A', 'A', 'A', 'B', 'A', 'A', 'B', 'B', 'B', 'B', 'A', 'B', 'A',
#        'B', 'A', 'A', 'A', 'B', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'B',
#        'B', 'B', 'A', 'B', 'A', 'A', 'B', 'A', 'B'], dtype='<U1')

# %%
pd.Series([1,2,2,4], index=pd.date_range('20230101', periods=4))
# Out:
# 2023-01-01    1
# 2023-01-02    2
# 2023-01-03    2
# 2023-01-04    4
# Freq: D, dtype: int64

# %%
pd.Categorical(['book', 'magazine'])
# Out:
# ['book', 'magazine']
# Categories (2, object): ['book', 'magazine']

# %%
df = pd.DataFrame(
    np.random.randn(6,4), 
    index= pd.date_range('20230101', freq='M', periods=6), 
    columns=['A', 'B', 'C', 'D']
                  )
df
# Out:
#                    A         B         C         D
# 2023-01-31 -1.472550  0.445486  0.227693  1.662151
# 2023-02-28  0.419347 -2.303611 -1.472487 -0.978498
# 2023-03-31 -1.416490 -0.152711  0.551602  0.452402
# 2023-04-30  0.265041 -0.339098  0.649572 -0.541386
# 2023-05-31  2.124530  0.232303  2.238267 -0.882543
# 2023-06-30  0.856766  2.211212  0.514682  1.138740

# %%
import datetime

now = datetime.datetime.now()

then = datetime.timedelta(weeks=4)
difference = now - then

difference.day
# Out:
# 26

# %%
df.loc['20230301':'20230501',['C', 'D']]
# Out:
#                    C         D
# 2023-03-31 -0.726772 -1.132934
# 2023-04-30 -0.760135  0.099778

# %%
df.iloc[1:4,2:3]
# Out:
#                    C
# 2023-02-28 -0.454618
# 2023-03-31 -0.726772
# 2023-04-30 -0.760135

# %%
df[df['A'] > 0.5]
# Out:
#                    A         B         C         D
# 2023-05-31  0.806342  1.356973 -0.070671 -1.528886

# %%
df2 = df.copy()
df2['E'] = np.random.choice(['book', 'magazine', 'flyer', 'book', 'magazine', 'flyer'], 
                            # 1000
      )
df2
# Out:
#                    A         B         C         D         E
# 2023-01-31 -1.472550  0.445486  0.227693  1.662151  magazine
# 2023-02-28  0.419347 -2.303611 -1.472487 -0.978498  magazine
# 2023-03-31 -1.416490 -0.152711  0.551602  0.452402  magazine
# 2023-04-30  0.265041 -0.339098  0.649572 -0.541386  magazine
# 2023-05-31  2.124530  0.232303  2.238267 -0.882543  magazine
# 2023-06-30  0.856766  2.211212  0.514682  1.138740  magazine

# %%
df2[df2['E'].isin(['book'])]
# Out:
#                    A         B         C         D     E
# 2023-01-31 -1.415465  0.217196  0.445882  0.958323  book
# 2023-04-30 -0.400179  0.655526 -0.760135  0.099778  book

# %%
df2[df2['E'] == 'book']
# Out:
#                    A         B         C         D     E
# 2023-01-31 -1.415465  0.217196  0.445882  0.958323  book
# 2023-04-30 -0.400179  0.655526 -0.760135  0.099778  book

# %%
df2
# Out:
#                    A         B         C         D         E
# 2023-01-31 -1.472550  0.445486  0.227693  1.662151  magazine
# 2023-02-28  0.419347 -2.303611 -1.472487 -0.978498  magazine
# 2023-03-31 -1.416490 -0.152711  0.551602  0.452402  magazine
# 2023-04-30  0.265041 -0.339098  0.649572 -0.541386  magazine
# 2023-05-31  2.124530  0.232303  2.238267 -0.882543  magazine
# 2023-06-30  0.856766  2.211212  0.514682  1.138740  magazine

# %%
# plt.subplots(2,2)
plt.figure(figsize=[10,4])
plt.subplot(131)
plt.plot(df2['B'], df2.index)
plt.subplot(133)
plt.plot(df2.index, df2['A'])
