# %% [markdown]
# # Reading and writing from streamlit to MongoDB
#
# ## 1. these are the collections
#
# ```JS
# async init() {
#     this.client = new MongoClient(this.uri);
#     await this.client.connect();
#     this.db = this.client.db(DB);
#     this.companiesCollection = this.db.collection('companies');
#     this.usersCollection = this.db.collection('users');
#     this.fundsCollection = this.db.collection('funds');
#     this.exchangeCollection = this.db.collection('exchange');
#     this.portfoliosCollection = this.db.collection('portfolios');
#     this.frameworksCollection = this.db.collection('frameworks');
#     this.metricMetaCollection = this.db.collection('metricMeta');
#     this.metricValuesCollection = this.db.collection('metricValues');
#
# const DB_URI = os.getenv('MONGO_URI');
# const DB = 'General';
# ```
#
# See: C:\Users\johan\Documents\GitHub\Supernova-PE\src\core\db.service.ts
#
# The `db.service` defines actions (like companiesCollection).
#
# ## 2. these are the fields
#
# The fields of the documents of the collections are spread out. For example here the metricValues are set:
#
# ```js
# async setMetricValue(metricMetaID) {
#   console.log('set metric value', this.metricValues[metricMetaID]);
#   let obj: DbMetricValue = {
#     company_link: this.company._id,
#     value: this.metricValues[metricMetaID].value,
#     reporting_period: this.request.reporting_period,
#     metric_meta_link: metricMetaID,
#     is_public: true
#   }
#   if (this.metricValues[metricMetaID]._id) {
#     await this.api.put('admin/metric-value', this.metricValues[metricMetaID]._id, {value: obj.value})
#   } else {
#     await this.api.post('admin/metric-value', obj)
#   }
#   this.getData(this.requestID);
# }
# ```
#
# See: C:\Users\johan\Documents\GitHub\Supernova-PE\angular-src\app\projects\admin\requests-item\requests-item.component.ts
#
# ## 3. schemas
#
# The schema is defined in C:\Users\johan\Documents\GitHub\Supernova-PE\src\shared\interfaces
#
# Typically this is done in [mongoose](https://www.mongodb.com/developer/languages/javascript/getting-started-with-mongodb-and-mongoose/).
#
# TODO:
# - Use the connection string to connect a python script, inspect a collection, document, and its fields.
# - Add and remove a document to see if that works.
# - connect streamlit

# %%
from pymongo import MongoClient
import pandas as pd

# %%
uri = os.getenv('MONGO_URI')
client = MongoClient(uri)

# database code goes here
db = client.General

# %%
db.list_collection_names()
# Out:
# ['users',
#  'companies',
#  'metricValues',
#  'exchange',
#  'funds',
#  'metricMeta',
#  'portfolios']

# %%
db.exchange.find_one()
# Out:
# {'_id': ObjectId('64632e73ee98577a8b286b3e'),
#  'title': 'Generic request',
#  'portfolio_link': '644c347fc69caac958b26d34',
#  'fund_link': '6447ef3b63bfe2715b407dd3',
#  'companies': [{'company_link': '64632e51ee98577a8b286b3c',
#    'requested_metrics': ['6449b2faa2927cd3aa323dcb',
#     '6449b304a2927cd3aa323dcc',
#     '6449b3c1a2927cd3aa323dda',
#     '6449b3caa2927cd3aa323ddb',
#     '6449b2b7a2927cd3aa323dc8']},
#   {'company_link': '64632e03ee98577a8b286b3a',
#    'requested_metrics': ['6449b2faa2927cd3aa323dcb',
#     '6449b304a2927cd3aa323dcc',
#     '6449b3c1a2927cd3aa323dda',
#     '6449b3caa2927cd3aa323ddb',
#     '6449b2b7a2927cd3aa323dc8',
#     '6449b348a2927cd3aa323dd3']},
#   {'company_link': '64632be0ee98577a8b286b2a',
#    'requested_metrics': ['6449b2faa2927cd3aa323dcb',
#     '6449b304a2927cd3aa323dcc',
#     '6449b3c1a2927cd3aa323dda',
#     '6449b3caa2927cd3aa323ddb',
#     '6449b2b7a2927cd3aa323dc8',
#     '6449b348a2927cd3aa323dd3']},
#   {'company_link': '6447eff42a81aa1fc0aa7e30',
#    'requested_metrics': ['6449b2faa2927cd3aa323dcb',
#     '6449b304a2927cd3aa323dcc',
#     '6449b3c1a2927cd3aa323dda',
#     '6449b3caa2927cd3aa323ddb',
#     '6449b2b7a2927cd3aa323dc8',
#     '6449b282a2927cd3aa323dc4',
#     '6449b348a2927cd3aa323dd3']},
#   {'company_link': '646330195ab3f926ff0db8df',
#    'requested_metrics': ['6449b348a2927cd3aa323dd3']}],
#  'metrics_set': True,
#  'reporting_period': ['10/22', '12/22'],
#  'deadline': '10/06/2023',
#  'sent_out': True}

# %%
users = []
for doc in db.companies.find():
    users.append(doc)
    
users
# Out:
# [{'_id': ObjectId('6447eff42a81aa1fc0aa7e30'),
#   'title': 'Pacific Carbon Capture',
#   'industry': 'Apps',
#   'revenue_category': '> 50m',
#   'is_publicly_available': 'true',
#   'is_invited': True,
#   'invited_by': ['6462e5e236b2f0c087c5310e',
#    '6462e92136b2f0c087c5310f',
#    '64632e73ee98577a8b286b3e',
#    '6492e5e7e3c1595c08087672',
#    '6492f331f6d3e3bbc9f0639c',
#    '64930745dae03dd14ac2b197',
#    '64942550c30a80751b8edcd1',
#    '6495747cdb62fd5ce34f6e9e',
#    '649d1fb3cb7292a2bac89c40',
#    '649d321abb31ea744f5672fd',
#    '649e929fbd4b0417b817e81a'],
#   'general_notes': 'very good company',
#   'metric_notes': '2332'},
#  {'_id': ObjectId('64632be0ee98577a8b286b2a'),
#   'title': 'Carbonfuture',
#   'description': 'Climate crisis fighters',
#   'revenue_category': '10-50m',
#   'industry': 'Biotechnology',
#   'is_publicly_available': True,
#   'invited_by': ['64632e73ee98577a8b286b3e', '64afb239c6d3b0ed2693dfc2']},
#  {'_id': ObjectId('64632e03ee98577a8b286b3a'),
#   'title': 'Equalture',
#   'description': 'Shaping the world of unbiased hiring for SMBs through data and gamification',
#   'revenue_category': '10-50m',
#   'industry': 'Artificial Intelligence',
#   'is_publicly_available': True,
#   'invited_by': ['64632e73ee98577a8b286b3e']},
#  {'_id': ObjectId('64632e51ee98577a8b286b3c'),
#   'title': 'Solar Monkey',
#   'description': "Output prediction and monitoring of PV systems by making solar the world's leading power supply!",
#   'revenue_category': '10-50m',
#   'industry': 'Natural Resources',
#   'is_publicly_available': True,
#   'invited_by': ['64632e73ee98577a8b286b3e',
#    '649d1fb3cb7292a2bac89c40',
#    '649d321abb31ea744f5672fd',
#    '649e929fbd4b0417b817e81a']},
#  {'_id': ObjectId('64632ed56c185884d6ae4618'),
#   'title': 'Circularise',
#   'description': 'Using blockchain to bring transparency to global supply chains and empower businesses to move towards a circular economy',
#   'revenue_category': '> 50m',
#   'industry': 'Financial Services',
#   'is_publicly_available': True,
#   'invited_by': ['649d1fb3cb7292a2bac89c40']},
#  {'_id': ObjectId('64632fa46c185884d6ae461c'),
#   'title': 'Circularise',
#   'description': 'Using blockchain to bring transparency to global supply chains and empower businesses to move towards a circular economy\n',
#   'revenue_category': '> 50m',
#   'industry': 'Financial Services',
#   'is_publicly_available': True},
#  {'_id': ObjectId('64632fe95ab3f926ff0db8dd'),
#   'title': 'Circularise',
#   'description': 'Using blockchain to bring transparency to global supply chains and empower businesses to move towards a circular economy',
#   'revenue_category': '> 50m',
#   'industry': 'Financial Services',
#   'is_publicly_available': True},
#  {'_id': ObjectId('646330195ab3f926ff0db8df'),
#   'title': 'Mobileye',
#   'description': 'Global leader in the development of vision technology for advanced driver assistance systems (ADAS) and autonomous driving',
#   'revenue_category': '> 50m',
#   'industry': 'Transportation',
#   'is_publicly_available': True},
#  {'_id': ObjectId('6463316d5ab3f926ff0db8e1'),
#   'title': 'Winnow',
#   'description': 'Develops artificial intelligence tools to help chefs run more profitable and sustainable kitchens',
#   'revenue_category': '> 50m',
#   'industry': 'Artificial Intelligence',
#   'is_publicly_available': True,
#   'invited_by': ['647403c5b861644d399fe63a', '647896d91b191bdfc94c9c49']},
#  {'_id': ObjectId('646d4fbba5e55088c08c316a'),
#   'title': 'dd',
#   'description': ''},
#  {'_id': ObjectId('646f289f2b5488aa92b09fba'),
#   'title': 'CarbonFuture',
#   'description': 'We track carbon from the air to the ground. We translate from carbon removal into credit. We trade carbon removal credits to companies.',
#   'revenue_category': '0-1m',
#   'industry': 'Sustainability',
#   'is_publicly_available': True},
#  {'_id': ObjectId('646f93f1fe83dc2c5d73605f'),
#   'title': 'Twiga Foods',
#   'description': 'Food logistics',
#   'revenue_category': '10-50m',
#   'industry': 'Food and Beverage',
#   'is_publicly_available': True,
#   'invited_by': ['647896d91b191bdfc94c9c49']},
#  {'_id': ObjectId('6473cb33f75522f7c60be8eb'),
#   'title': '2X Global',
#   'description': 'A global company selling various products',
#   'revenue_category': '1-2m',
#   'industry': 'Manufacturing',
#   'is_publicly_available': True},
#  {'_id': ObjectId('6473cff13fc111365f561679'),
#   'title': '2X Global',
#   'description': ''},
#  {'_id': ObjectId('64740409b861644d399fe63b'),
#   'title': 'Test',
#   'description': 'test2',
#   'revenue_category': '2-5m',
#   'industry': 'Apps',
#   'is_publicly_available': True},
#  {'_id': ObjectId('64740453b861644d399fe63d'),
#   'title': 'Test Company II',
#   'description': 'Test Company II',
#   'revenue_category': '10-50m',
#   'industry': 'Advertising',
#   'is_publicly_available': True,
#   'invited_by': ['647896d91b191bdfc94c9c49']},
#  {'_id': ObjectId('6474075b8f98c4e9e05b3b09'),
#   'title': 'TestCompany III',
#   'description': 'TestCompany III',
#   'revenue_category': '0-1m',
#   'industry': 'Apps',
#   'is_publicly_available': True},
#  {'_id': ObjectId('649d218bcb7292a2bac89c41'),
#   'title': 'Resource Innovation Inc. ',
#   'description': 'Resource Innovation Inc. is a pioneering company that develops and implements cutting-edge solutions to optimize resource utilization, foster sustainability, and drive circular economy principles across industries.',
#   'revenue_category': '10-50m',
#   'industry': 'Agriculture and Farming',
#   'is_publicly_available': True},
#  {'_id': ObjectId('649e915bbd4b0417b817e817'),
#   'title': 'Atlantic Carbon Inc. ',
#   'description': '',
#   'industry': 'Sustainability',
#   'revenue_category': '2-5m'}]

# %% [markdown]
# ## Adding a collection and a document inside it
#
# The collection is created when you add a document

# %%
import datetime
post = {
    "author": "Mike",
    "text": "My first blog post!",
    "tags": ["mongodb", "python", "pymongo"],
    "date": datetime.datetime.now(tz=datetime.timezone.utc),
}

test = db.test
test_id = test.insert_one(post).inserted_id
test_id
# Out:
# ObjectId('64ca8d26c7e45b4cc5e662d7')

# %%
db.list_collection_names()
# Out:
# ['users',
#  'companies',
#  'metricValues',
#  'test',
#  'exchange',
#  'funds',
#  'metricMeta',
#  'portfolios']

# %%
for f in db.test.find({}):
    print(f)
# Out:
# {'_id': ObjectId('64ca8d26c7e45b4cc5e662d7'), 'author': 'Mike', 'text': 'My first blog post!', 'tags': ['mongodb', 'python', 'pymongo'], 'date': datetime.datetime(2023, 8, 2, 17, 6, 46, 112000)}

# %%
db.test.drop()

# %%
db.list_collection_names()
# Out:
# ['users',
#  'companies',
#  'metricValues',
#  'exchange',
#  'funds',
#  'metricMeta',
#  'portfolios']

# %% [markdown]
# ## Adding a date field based on the id

# %%
db.users.find_one()['_id']
# Out:
# ObjectId('6447ef3b63bfe2715b407dd4')

# %%
from bson.objectid import ObjectId
from datetime import datetime

users = []
for doc in db.users.find():
    id_string = doc['_id']
    
    # Convert string to ObjectId
    id_object = ObjectId(id_string)
    
    # Extract the timestamp and convert it to datetime
    creation_time = id_object.generation_time

    # Now let's add this to the document as a new field
    filter = {'_id': id_object}
    new_values = {"$set": {'createdAt': creation_time}}

    db.users.update_one(filter, new_values)

# %%
users = []
for doc in db.users.find():
    users.append(doc)
    
users
# Out:
# [{'_id': ObjectId('6447ef3b63bfe2715b407dd4'),
#   'name': 'Jefferson II',
#   'email': 'jeff@supernova.ai',
#   'password': 'not-so-secure',
#   'fund_link': '6447ef3b63bfe2715b407dd3',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 4, 25, 15, 18, 19)},
#  {'_id': ObjectId('6448158c1b576b1a4524c721'),
#   'name': 'Jefferson',
#   'email': 'jeff1@supernova.ai',
#   'password': 'not-so-secure',
#   'fund_link': '6448158c1b576b1a4524c720',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 4, 25, 18, 1, 48)},
#  {'_id': ObjectId('6448261221f446cb608e7002'),
#   'email': 'test@email.com',
#   'name': 'John Doe',
#   'type': 'company-manager',
#   'company_link': '6448261221f446cb608e7001',
#   'password': '8x5#SvJ#',
#   'createdAt': datetime.datetime(2023, 4, 25, 19, 12, 18)},
#  {'_id': ObjectId('644831372a81aa1fc0aa7e31'),
#   'email': 'max@supernova.ai',
#   'name': 'Max',
#   'password': '1oC0!PJf4Y@1',
#   'type': 'admin',
#   'createdAt': datetime.datetime(2023, 4, 25, 19, 59, 51)},
#  {'_id': ObjectId('644c517d9cbd798560c581f0'),
#   'email': 'test@test',
#   'name': 'test',
#   'type': 'company-manager',
#   'company_link': '644c517d9cbd798560c581ef',
#   'password': '5enAr<|!',
#   'createdAt': datetime.datetime(2023, 4, 28, 23, 6, 37)},
#  {'_id': ObjectId('644c51a09cbd798560c581f2'),
#   'email': 'cool company',
#   'name': 'cool company',
#   'type': 'company-manager',
#   'company_link': '644c51a09cbd798560c581f1',
#   'password': '0nR]ztT%',
#   'createdAt': datetime.datetime(2023, 4, 28, 23, 7, 12)},
#  {'_id': ObjectId('644c52989cbd798560c581f4'),
#   'email': 'email@address',
#   'name': 'Cool Manager',
#   'type': 'company-manager',
#   'company_link': '644c52989cbd798560c581f3',
#   'password': 'Qg9Dk-l:',
#   'createdAt': datetime.datetime(2023, 4, 28, 23, 11, 20)},
#  {'_id': ObjectId('644c53619cbd798560c581f8'),
#   'email': 'ppppp@',
#   'name': '',
#   'type': 'company-manager',
#   'company_link': '644c53619cbd798560c581f7',
#   'password': ',N7s!Ob7',
#   'createdAt': datetime.datetime(2023, 4, 28, 23, 14, 41)},
#  {'_id': ObjectId('644d3a73b8843bc111a3294b'),
#   'email': 'asd@asd',
#   'name': 'New Manager',
#   'type': 'company-manager',
#   'company_link': '644d3a73b8843bc111a3294a',
#   'password': 'e:2[n0Ti',
#   'createdAt': datetime.datetime(2023, 4, 29, 15, 40, 35)},
#  {'_id': ObjectId('644d5e1098b0c737be5090bd'),
#   'email': 'test23@email.com',
#   'name': 'John Doe',
#   'type': 'company-manager',
#   'company_link': '644d5e1098b0c737be5090bc',
#   'password': '&tNzC7uv',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 12, 32)},
#  {'_id': ObjectId('644d5ed398b0c737be5090bf'),
#   'email': 'mike@supernova.ai',
#   'name': 'Mike',
#   'type': 'company-manager',
#   'company_link': '644d5ed398b0c737be5090be',
#   'password': '?yre,Ql3',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 15, 47)},
#  {'_id': ObjectId('644d5f1a98b0c737be5090c1'),
#   'email': 'test@test.com',
#   'name': '',
#   'type': 'company-manager',
#   'company_link': '644d5f1a98b0c737be5090c0',
#   'password': '1JIR&+v>',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 16, 58)},
#  {'_id': ObjectId('644d5f5798b0c737be5090c3'),
#   'email': 'bad@dj.com',
#   'name': 'Darth',
#   'type': 'company-manager',
#   'company_link': '644d5f5798b0c737be5090c2',
#   'password': 'W:=q9z<?',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 17, 59)},
#  {'_id': ObjectId('644d5fb698b0c737be5090c5'),
#   'email': 'john@dj.com',
#   'name': 'john',
#   'type': 'company-manager',
#   'company_link': '644d5fb598b0c737be5090c4',
#   'password': 'iC.C0n)p',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 19, 34)},
#  {'_id': ObjectId('644d67db98b0c737be5090c7'),
#   'email': 'blah@blah.com',
#   'name': '',
#   'type': 'company-manager',
#   'company_link': '644d67db98b0c737be5090c6',
#   'password': 'MTu2dOr+',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 54, 19)},
#  {'_id': ObjectId('644d67fb98b0c737be5090c9'),
#   'email': 'ai@ai.com',
#   'name': '',
#   'type': 'company-manager',
#   'company_link': '644d67fb98b0c737be5090c8',
#   'password': '<7Uq*)O2',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 54, 51)},
#  {'_id': ObjectId('644d684b98b0c737be5090cb'),
#   'email': 'super@super.com',
#   'name': 'Superman',
#   'type': 'company-manager',
#   'company_link': '644d684b98b0c737be5090ca',
#   'password': '53zK;!}T',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 56, 11)},
#  {'_id': ObjectId('644d692aef1b32b0d9d56f8b'),
#   'email': 'evgeny@supernova.ai',
#   'name': 'Pacific Carbon Capture',
#   'type': 'company-manager',
#   'company_link': '6447eff42a81aa1fc0aa7e30',
#   'password': '4n<BVj[(',
#   'createdAt': datetime.datetime(2023, 4, 29, 18, 59, 54)},
#  {'_id': ObjectId('644ede8d42643659c6fe8994'),
#   'email': 'max1@kilazi.com',
#   'name': 'Max1',
#   'type': 'company-manager',
#   'company_link': '644ede8d42643659c6fe8992',
#   'password': '[Ey}_W1.',
#   'createdAt': datetime.datetime(2023, 4, 30, 21, 33, 1)},
#  {'_id': ObjectId('644f0e405d6670717296cb0a'),
#   'email': 'test@est.com',
#   'name': 'test',
#   'type': 'company-manager',
#   'company_link': '644f0e405d6670717296cb09',
#   'password': '7h7)Uff3',
#   'createdAt': datetime.datetime(2023, 5, 1, 0, 56, 32)},
#  {'_id': ObjectId('644f18743494e9c6f47a56d0'),
#   'email': 'asd',
#   'name': 'te',
#   'type': 'company-manager',
#   'company_link': '644f18743494e9c6f47a56cf',
#   'password': '8JVFXL]r',
#   'createdAt': datetime.datetime(2023, 5, 1, 1, 40, 4)},
#  {'_id': ObjectId('644f2b68f6936bc25aeba2e5'),
#   'email': 'test@tessdsd.sr',
#   'name': 'tester',
#   'password': ':>EzB_=2',
#   'type': 'fund-investor',
#   'fund_link': '6447ef3b63bfe2715b407dd3',
#   'createdAt': datetime.datetime(2023, 5, 1, 3, 0, 56)},
#  {'_id': ObjectId('644fb4bdfc56e8ee339e35da'),
#   'email': 'gefireturkiye@gmail.com',
#   'name': 'Jeff new',
#   'type': 'company-manager',
#   'company_link': '644fb4bdfc56e8ee339e35d9',
#   'password': 'i#DE6?%-',
#   'createdAt': datetime.datetime(2023, 5, 1, 12, 46, 53)},
#  {'_id': ObjectId('64632be1ee98577a8b286b2b'),
#   'email': 'johannes@carbon.com',
#   'name': 'Johannes',
#   'type': 'company-manager',
#   'company_link': '64632be0ee98577a8b286b2a',
#   'password': '9!lcR(E0',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 8, 17)},
#  {'_id': ObjectId('64632e03ee98577a8b286b3b'),
#   'email': 'john@equalture.test',
#   'name': 'John',
#   'type': 'company-manager',
#   'company_link': '64632e03ee98577a8b286b3a',
#   'password': 'C6X|-[Js',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 17, 23)},
#  {'_id': ObjectId('64632e51ee98577a8b286b3d'),
#   'email': 'james@solar-monkey.test',
#   'name': 'James',
#   'type': 'company-manager',
#   'company_link': '64632e51ee98577a8b286b3c',
#   'password': 'o{j)8cZ2',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 18, 41)},
#  {'_id': ObjectId('64632ed56c185884d6ae4619'),
#   'email': 'Mark@email.com',
#   'name': 'Mark',
#   'type': 'company-manager',
#   'company_link': '64632ed56c185884d6ae4618',
#   'password': '2u)2/oBJ',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 20, 53)},
#  {'_id': ObjectId('64632fa46c185884d6ae461d'),
#   'email': 'Mark2@email.com',
#   'name': 'Mark',
#   'type': 'company-manager',
#   'company_link': '64632fa46c185884d6ae461c',
#   'password': 'jaS}U-s6',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 24, 20)},
#  {'_id': ObjectId('64632fea5ab3f926ff0db8de'),
#   'email': 'Mark3@email.com',
#   'name': 'Mark',
#   'type': 'company-manager',
#   'company_link': '64632fe95ab3f926ff0db8dd',
#   'password': ']V#1,}4u',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 25, 30)},
#  {'_id': ObjectId('646330195ab3f926ff0db8e0'),
#   'email': 'Lynn@email.com',
#   'name': 'Lynn',
#   'type': 'company-manager',
#   'company_link': '646330195ab3f926ff0db8df',
#   'password': '=ggU<K3b',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 26, 17)},
#  {'_id': ObjectId('6463316d5ab3f926ff0db8e2'),
#   'email': 'Sam33@email.com',
#   'name': 'Sam',
#   'type': 'company-manager',
#   'company_link': '6463316d5ab3f926ff0db8e1',
#   'password': '|Ca{2}m7',
#   'createdAt': datetime.datetime(2023, 5, 16, 7, 31, 57)},
#  {'_id': ObjectId('646d4bc414460ab65ecf1832'),
#   'email': 'maxmax@supernova.ai',
#   'name': 'Máximo',
#   'password': 'test',
#   'fund_link': '646d4bc314460ab65ecf1831',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 5, 23, 23, 27)},
#  {'_id': ObjectId('646d4fbca5e55088c08c316b'),
#   'email': 'maxmax1@supernova.ai',
#   'name': 'dd',
#   'password': 'test',
#   'company_link': '646d4fbba5e55088c08c316a',
#   'type': 'company-manager',
#   'createdAt': datetime.datetime(2023, 5, 23, 23, 43, 56)},
#  {'_id': ObjectId('646dd01d2e45a40e2e8b4f3a'),
#   'email': 'frank@ticc.io',
#   'name': 'Thomas Mahler',
#   'password': 'supernova2023',
#   'fund_link': '646dd01d2e45a40e2e8b4f39',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 5, 24, 8, 51, 41)},
#  {'_id': ObjectId('646f1a77f5a36d39b8610470'),
#   'email': 'yasmin@4impact.vc',
#   'name': 'Yasmin Venema',
#   'password': '4impact2023',
#   'fund_link': '646f1a77f5a36d39b861046f',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 5, 25, 8, 21, 11)},
#  {'_id': ObjectId('646f289f2b5488aa92b09fbb'),
#   'email': 'frank.tobe@yieldinc.com',
#   'name': 'Frank Tobé',
#   'type': 'company-manager',
#   'company_link': '646f289f2b5488aa92b09fba',
#   'password': '&K}7;kEr',
#   'createdAt': datetime.datetime(2023, 5, 25, 9, 21, 35)},
#  {'_id': ObjectId('646f93f2fe83dc2c5d736060'),
#   'email': 'peter@bullshit.com',
#   'name': 'Peter John',
#   'type': 'company-manager',
#   'company_link': '646f93f1fe83dc2c5d73605f',
#   'password': 'Izc#v3Ij',
#   'createdAt': datetime.datetime(2023, 5, 25, 16, 59, 30)},
#  {'_id': ObjectId('6473cac13fc111365f561675'),
#   'email': 'franktobe444@gmail.com',
#   'name': 'Jonah Hill',
#   'password': 'supernova2023',
#   'fund_link': '6473cac13fc111365f561674',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 5, 28, 21, 42, 25)},
#  {'_id': ObjectId('6473cb33f75522f7c60be8ec'),
#   'email': 'bizzy@2xglobal.io',
#   'name': 'Bizzy Monsoon',
#   'type': 'company-manager',
#   'company_link': '6473cb33f75522f7c60be8eb',
#   'password': 'mLvq22j$',
#   'createdAt': datetime.datetime(2023, 5, 28, 21, 44, 19)},
#  {'_id': ObjectId('6473cff13fc111365f56167a'),
#   'email': 'frank@2xglobal.ai',
#   'name': 'Frank Tobe',
#   'password': 'supernova2023',
#   'company_link': '6473cff13fc111365f561679',
#   'type': 'company-manager',
#   'createdAt': datetime.datetime(2023, 5, 28, 22, 4, 33)},
#  {'_id': ObjectId('6474040ab861644d399fe63c'),
#   'email': 'test@test.ss',
#   'name': 'test@test.ss',
#   'type': 'company-manager',
#   'company_link': '64740409b861644d399fe63b',
#   'password': 'F/At8OO|',
#   'createdAt': datetime.datetime(2023, 5, 29, 1, 46, 50)},
#  {'_id': ObjectId('64740453b861644d399fe63e'),
#   'email': 'test@testtt.com',
#   'name': 'Test',
#   'type': 'company-manager',
#   'company_link': '64740453b861644d399fe63d',
#   'password': '/i,T^Px5',
#   'createdAt': datetime.datetime(2023, 5, 29, 1, 48, 3)},
#  {'_id': ObjectId('6474075b8f98c4e9e05b3b0a'),
#   'email': 'test@testesss.com',
#   'name': 'Test',
#   'type': 'company-manager',
#   'company_link': '6474075b8f98c4e9e05b3b09',
#   'password': '+Km4$W+L',
#   'createdAt': datetime.datetime(2023, 5, 29, 2, 0, 59)},
#  {'_id': ObjectId('6492e3e8e3c1595c0808766f'),
#   'email': 'frank@supernova.ai',
#   'name': 'Jonah Hewitt',
#   'password': 'borealis2023',
#   'fund_link': '6492e3e8e3c1595c0808766e',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 6, 21, 11, 50)},
#  {'_id': ObjectId('649d1f40cb7292a2bac89c3e'),
#   'email': 'jonah@borealiscapital.com',
#   'name': 'Jonah Hewitt',
#   'password': 'borealis2023',
#   'fund_link': '649d1f40cb7292a2bac89c3d',
#   'type': 'fund-investor',
#   'createdAt': datetime.datetime(2023, 6, 29, 6, 5, 52)},
#  {'_id': ObjectId('649d218bcb7292a2bac89c42'),
#   'email': 'tom@resourceinnovation.io',
#   'name': 'Tom Holland',
#   'type': 'company-manager',
#   'company_link': '649d218bcb7292a2bac89c41',
#   'password': '4eJ-j3l{',
#   'createdAt': datetime.datetime(2023, 6, 29, 6, 15, 39)},
#  {'_id': ObjectId('649e915bbd4b0417b817e818'),
#   'email': 'pedro@atlanticcarbon.io',
#   'name': 'Pedro Almeida',
#   'password': 'atlantic2023',
#   'company_link': '649e915bbd4b0417b817e817',
#   'type': 'company-manager',
#   'createdAt': datetime.datetime(2023, 6, 30, 8, 24, 59)}]

# %% [markdown]
# And i'll delete it again because I don't know what will happen with those interfaces.

# %%
db.users.update_many({}, {'$unset': {'createdAt': ""}})

# %%
db.users.find_one()
# Out:
# {'_id': ObjectId('6447ef3b63bfe2715b407dd4'),
#  'name': 'Jefferson II',
#  'email': 'jeff@supernova.ai',
#  'password': 'not-so-secure',
#  'fund_link': '6447ef3b63bfe2715b407dd3',
#  'type': 'fund-investor'}

# %% [markdown]
# ## Always close

# %%
# Close the connection to MongoDB when you're done.
client.close()

# %% [markdown]
# ## Load Mongodb directly inside pandas
# https://pypi.org/project/pymongoarrow/

# %%
import pymongoarrow as pma

# %%
from pymongoarrow.monkey import patch_all
patch_all() # to add pymongoarrow's functionality to all collections

# %% [markdown]
# ```py
# from pymongoarrow.api import Schema
# schema = Schema({"_id": int, "qty": float})
#
# from pymongo import MongoClient
# client = MongoClient()
# client.db.data.insert_many(
#    [{"_id": 1, "qty": 25.4}, {"_id": 2, "qty": 16.9}, {"_id": 3, "qty": 2.3}]
# )
# ```

# %%
db.list_collection_names()
# Out:
# ['users',
#  'companies',
#  'metricValues',
#  'exchange',
#  'funds',
#  'metricMeta',
#  'portfolios']

# %%
data_frame = db.metricMeta.find_pandas_all({}) #, schema=schema)
data_frame[['code', 'title', 'description']]
# Out:
#                                                  code  \
# 0                    greenhouse_gas_emissions_avoided
# 1                  greenhouse_gas_emissions_mitigated
# 2                 km2_of_forest_monitored_for_clients
# 3                       candidates_assessed_bias_free
# 4                                         water_saved
# 5                       aum_to_invest_in_climate_tech
# 6                               active_platform_users
# 7                               ghg_emissions_scope_1
# 8                               ghg_emissions_scope_2
# 9                               ghg_emissions_scope_3
# 10                                      ghg_emissions
# 11                                   carbon_footprint
# 12                                      ghg_intensity
# 13    exposure_to_companies_in_the_fossil_fuel_sector
# 14          share_of_non_renewable_energy_consumption
# 15           share_of_non_renewable_energy_production
# 16  energy_consumption_intensity_per_high_impact_c...
# 17  activities_negatively_affecting_high_impact_cl...
# 18                                 emissions_to_water
# 19                              hazardous_waste_ratio
# 20                violations_of_the_un_global_compact
# 21  lack_of_processes_and_compliance_mechanisms_to...
# 22                          unadjusted_gender_pay_gap
# 23                             board_gender_diversity
# 24                  exposure_to_controversial_weapons
# 25                                               None
# 26                                               None
#
#                                                 title  \
# 0                    Greenhouse Gas Emissions Avoided
# 1                  Greenhouse Gas Emissions Mitigated
# 2                 KM2 of Forest Monitored for Clients
# 3                       Candidates Assessed Bias-Free
# 4                                         Water Saved
# 5                       AuM to Invest in Climate Tech
# 6                               Active Platform Users
# 7                               GHG Emissions Scope 1
# 8                               GHG Emissions Scope 2
# 9                               GHG Emissions Scope 3
# 10                                      GHG Emissions
# 11                                   Carbon Footprint
# 12                                      GHG Intensity
# 13    Exposure to companies in the fossil fuel sector
# 14          Share of non-renewable energy consumption
# 15           Share of non-renewable energy production
# 16  Energy consumption intensity per high impact c...
# 17  Activities negatively affecting high-impact cl...
# 18                                 Emissions to water
# 19                              Hazardous waste ratio
# 20                Violations of the UN Global Compact
# 21  Lack of processes and compliance mechanisms to...
# 22                          Unadjusted gender pay gap
# 23                             Board gender diversity
# 24                  Exposure to controversial weapons
# 25                        Cats guarding the perimeter
# 26                      Passengers Transported Safely
#
#                                           description
# 0   Amount of greenhouse gas (GHG) emissions avoid...
# 1   Amount of greenhouse gas (GHG) emissions mitig...
# 2   This metric represents the number of square ki...
# 3   This metric represents the number of job candi...
# 4
# 5
# 6
# 7
# 8
# 9
# 10             Cumulative scope 1, 2 and 3 emissions.
# 11
# 12
# 13      Company activities in the fossil fuel sector.
# 14  Share of non-renewable energy consumption of i...
# 15  Share of non-renewable energy production of co...
# 16  For companies active in agriculture, forestry ...
# 17  Does company own sites / operations located in...
# 18  Tonnes of emissions to water generated by company
# 19  Tonnes of hazardous waste and radioactive wast...
# 20  Involvement in violations of the UNGC principl...
# 21  Policies to monitor compliance with the UNGC p...
# 22  % difference between pay for women and men in ...
# 23  Ratio of female to male board members in inves...
# 24  Involvement in the manufacture or selling of c...
# 25  Its important to know how much chicken is bein...
# 26                                   Safe transport.

# %% [markdown]
# ## schemas
# Not really necessary, only to select columns.
#
# ```py
# from pymongoarrow.api import Schema
# schema = Schema({'_id': int, 'amount': float, 'last_updated': datetime})
# ```
# see: https://mongo-arrow.readthedocs.io/en/latest/data_types.html
#
# ## find
# We are now ready to query our data. Let’s start by running a find operation to load all records with a non-zero amount as a pandas.DataFrame:
#
# ```py
# df = client.db.data.find_pandas_all({'amount': {'$gt': 0}}, schema=schema)
#
# # pandas
# df = client.db.data.aggregate_pandas_all([{'$match': {'amount': {'$lte': 10}}}], schema=schema)
# ```
#
#
# ## write back
# ```py
# from pymongoarrow.api import write
# from pymongo import MongoClient
# coll = MongoClient().db.my_collection
# write(coll, df)
# ```

# %% [markdown]
# # Mongodb to streamlit
#
# From tutorial page:

# %%
# streamlit_app.py

import streamlit as st
import pymongo

# Initialize connection.
# Uses st.cache_resource to only run once.
@st.cache_resource
def init_connection():
    return pymongo.MongoClient(**st.secrets["mongo"])

client = init_connection()

# Pull data from the collection.
# Uses st.cache_data to only rerun when the query changes or after 10 min.
@st.cache_data(ttl=600) # show_spinner=False
def get_data():
    db = client.mydb
    items = db.mycollection.find()
    items = list(items)  # make hashable for st.cache_data
    return items

items = get_data()

# Print results.
for item in items:
    st.write(f"{item['name']} has a :{item['pet']}:")

# %% [markdown]
# writing any text, code or images to mongodb should follow the flow above. `insert_one` or `update_one`

# %% [markdown]
# Most important next steps are:
#
# - make the portfolio visible in the dashboard/data.
# - save the graphs/code somewhere that runs the code

# %% [markdown]
# ## Below replaces this in the streamlit visualiser:
#
# ```py
# url = "https://github.com/JohannesVC/streamlit/tree/master/supernova_app/Visualiser/data/supernova_xs.pickle"
# data = requests.get(url).content
# datasets["Supernova sample dataset"] = pd.read_pickle(BytesIO(data))
# ```

# %%
from pymongo import MongoClient
import pandas as pd
import os

uri = os.getenv('MONGO_URI')

client = MongoClient(uri)

# database code goes here
db = client.General

df = pd.read_pickle(r'C:\Users\johan\Documents\GitHub\supernova python\supernova_app\visualiser\data\supernova_xs.pickle')

df_dict = df.to_dict(orient='records')

# careful!
# db.visualiser_sample.insert_many(df_dict)

db['visualiser_sample'].find_one()
